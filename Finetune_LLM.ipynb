# %% [markdown]
# Install Required Dependencies

# %%
# !pip install -q accelerate peft bitsandbytes transformers trl datasets evaluate rouge_score
# !pip install -q torch torchvision torchaudio --index-url https://download.pytorch.org/whl/cu121
# Out:
#   Preparing metadata (setup.py) ... done
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.3/61.3 MB 12.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 511.9/511.9 kB 28.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 84.1/84.1 kB 5.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 4.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 68.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 36.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 45.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 1.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 6.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 11.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 8.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 7.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 188.7/188.7 MB 7.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 42.6 MB/s eta 0:00:00
#   Building wheel for rouge_score (setup.py) ... done

# %% [markdown]
# Import Required Libraries

# %%
import os
import torch
import random
import warnings
import evaluate
from datasets import load_dataset
from transformers import (
    AutoModelForCausalLM,
    AutoTokenizer,
    BitsAndBytesConfig,
    TrainingArguments,
    pipeline,
    logging
)
from peft import LoraConfig, get_peft_model, prepare_model_for_kbit_training
from trl import SFTTrainer
from tqdm import tqdm
warnings.filterwarnings('ignore')
logging.set_verbosity(logging.CRITICAL)
# AutoModelForCausalLM: This class is specifically designed for causal language modeling, i.e. next-token prediction/generation, which is the standard for most large language models (LLMs) like Mistral, GPT, or Llama
# AutoTokenizer: This class automatically load the correct tokenizer for a given pre-trained model
# NB: Different pre-trained models (like BERT, GPT-2, RoBERTa, etc.) use different tokenizers with unique vocabularies and rules
# SFTTrainer from trl (Transformer Reinforcement Learning): A trainer specifically designed for Supervised Fine-Tuning (SFT) of language models

# %%
print(f"PyTorch version: {torch.__version__}")
print(f"CUDA available: {torch.cuda.is_available()}")
if torch.cuda.is_available():
    print(f"GPU: {torch.cuda.get_device_name(0)}")
# Out:
# PyTorch version: 2.6.0+cu124
# CUDA available: True
# GPU: Tesla T4

# %% [markdown]
# Authentication and Model Access

# %%
from huggingface_hub import login
login(token="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")

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# Configure Model and Training Parameters

# %%
# Model configuration
model_name = "TinyLlama/TinyLlama-1.1B-Chat-v1.0"
new_model = "tinyllama-1.1b-lora-finetuned"
# new_model is used to define the name of the directory where your fine-tuned model and tokenizer will be saved after training is complete

# LoRA configuration parameters
lora_r = 8  # Rank of adaptation
lora_alpha = 16  # LoRA scaling parameter
lora_dropout = 0.05  # Dropout probability

# %% [markdown]
# Set Up 4-bit Quantization

# %%
compute_dtype = getattr(torch, "float16")

bnb_config = BitsAndBytesConfig(
    load_in_4bit=True, #  Activates 4-bit quantized weights for the model
    bnb_4bit_use_double_quant=False,
    bnb_4bit_quant_type="nf4", # Specifies the quantization type: NormalFloat4, optimized for LLMs
    bnb_4bit_compute_dtype=compute_dtype
)
# In 4-bit quantization, each weight is limited to just 16 possible values (2^4 values)

# %% [markdown]
# Load Base Model and Tokenizer

# %%
# Load the base model with quantization
model = AutoModelForCausalLM.from_pretrained(
    model_name,
    quantization_config=bnb_config,
    device_map="auto",
    trust_remote_code=True,
)

model.config.use_cache = False
model.config.pretraining_tp = 1 # No tensor parallelism

# Load tokenizer
tokenizer = AutoTokenizer.from_pretrained(model_name, trust_remote_code=True)
tokenizer.pad_token = tokenizer.eos_token
tokenizer.padding_side = "right"  # Recommended for decoder-only models
# For TinyLlama-1.1B-Chat-v1.0, the embedding dimension (or hidden size) is 2048 i.e. each token is represented by a vector of size 2048
# Out:
# config.json:   0%|          | 0.00/608 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/2.20G [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/124 [00:00<?, ?B/s]
# tokenizer_config.json: 0.00B [00:00, ?B/s]
# tokenizer.model:   0%|          | 0.00/500k [00:00<?, ?B/s]
# tokenizer.json: 0.00B [00:00, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/551 [00:00<?, ?B/s]

# %% [markdown]
# Prepare Model for LoRA Training

# %%
def print_trainable_parameters(model):
    trainable_params = 0
    all_param = 0
    for _, param in model.named_parameters():
        all_param += param.numel()
        if param.requires_grad:
            trainable_params += param.numel()
    print(f"trainable params: {trainable_params} || all params: {all_param} || trainable%: {100 * trainable_params / all_param}")

print_trainable_parameters(model)

# %%
model = prepare_model_for_kbit_training(model)

# Configure LoRA
peft_config = LoraConfig(
    lora_alpha=lora_alpha,
    lora_dropout=lora_dropout,
    r=lora_r,
    bias="none",
    task_type="CAUSAL_LM", # Autoregressive model, it uses everything it’s generated so far to predict the next token
    target_modules=[
        "q_proj",
        "k_proj",
        "v_proj",
        "o_proj",
        "gate_proj",
        "up_proj",
        "down_proj",
        "lm_head",
    ]
)

# Apply LoRA to the model
model = get_peft_model(model, peft_config)
# It essentially adds the small, trainable LoRA matrices (A and B) to the specified target_modules of the model, while keeping the original model weights frozen

# %%
print_trainable_parameters(model)
# Original Model Weights: The original pre-trained model's weights (W) are frozen i.e. they are not updated during the fine-tuning (requires_grad=False)
# LoRA Adapter Matrices: LoRA introduces two small matrices, A and B, the parameters within these matrices are trainable (requires_grad=True)
# This is why the percentage of trainable parameters is very small compared to the total number of parameters in the original model
# Out:
# trainable params: 6580224 || all params: 622186496 || trainable%: 1.0575967241821975

# %% [markdown]
# Prepare Training Dataset

# %%
dataset = load_dataset("tatsu-lab/alpaca", split="train") # Using Alpaca

print(dataset)
print(dataset.shape)
first_few_examples = dataset.select(range(5))
print(first_few_examples['text'])
# Out:
# README.md: 0.00B [00:00, ?B/s]
# data/train-00000-of-00001-a09b74b3ef9c3b(…):   0%|          | 0.00/24.2M [00:00<?, ?B/s]
# Generating train split:   0%|          | 0/52002 [00:00<?, ? examples/s]
# Dataset({
#     features: ['instruction', 'input', 'output', 'text'],
#     num_rows: 52002
# })
# (52002, 4)
# Column(['Below is an instruction that describes a task. Write a response that appropriately completes the request.\n\n### Instruction:\nGive three tips for staying healthy.\n\n### Response:\n1.Eat a balanced diet and make sure to include plenty of fruits and vegetables. \n2. Exercise regularly to keep your body active and strong. \n3. Get enough sleep and maintain a consistent sleep schedule.', 'Below is an instruction that describes a task. Write a response that appropriately completes the request.\n\n### Instruction:\nWhat are the three primary colors?\n\n### Response:\nThe three primary colors are red, blue, and yellow.', 'Below is an instruction that describes a task. Write a response that appropriately completes the request.\n\n### Instruction:\nDescribe the structure of an atom.\n\n### Response:\nAn atom is made up of a nucleus, which contains protons and neutrons, surrounded by electrons that travel in orbits around the nucleus. The protons and neutrons have a positive charge, while the electrons have a negative charge, resulting in an overall neutral atom. The number of each particle determines the atomic number and the type of atom.', 'Below is an instruction that describes a task. Write a response that appropriately completes the request.\n\n### Instruction:\nHow can we reduce air pollution?\n\n### Response:\nThere are a number of ways to reduce air pollution, such as shifting to renewable energy sources, encouraging the use of public transportation, prohibiting the burning of fossil fuels, implementing policies to reduce emissions from industrial sources, and implementing vehicle emissions standards. Additionally, individuals can do their part to reduce air pollution by reducing car use, avoiding burning materials such as wood, and changing to energy efficient appliances.', 'Below is an instruction that describes a task. Write a response that appropriately completes the request.\n\n### Instruction:\nDescribe a time when you had to make a difficult decision.\n\n### Response:\nI had to make a difficult decision when I was working as a project manager at a construction company. I was in charge of a project that needed to be completed by a certain date in order to meet the client’s expectations. However, due to unexpected delays, we were not able to meet the deadline and so I had to make a difficult decision. I decided to extend the deadline, but I had to stretch the team’s resources even further and increase the budget. Although it was a risky decision, I ultimately decided to go ahead with it to ensure that the project was completed on time and that the client’s expectations were met. The project was eventually successfully completed and this was seen as a testament to my leadership and decision-making abilities.'])

# %%
# Format data for TinyLlama chat format
def format_prompts(examples):
    instructions = examples["instruction"]
    inputs = examples["input"]
    outputs = examples["output"]
    # print(examples["instruction"][0])

    texts = []
    for instruction, input_text, output in zip(instructions, inputs, outputs):
        # TinyLlama uses ChatML format: <|system|>, <|user|>, <|assistant|>
        if input_text:
            text = f"<|system|>\nYou are a helpful AI assistant.</s>\n<|user|>\n{instruction}\n\n{input_text}</s>\n<|assistant|>\n{output}</s>"
        else:
            text = f"<|system|>\nYou are a helpful AI assistant.</s>\n<|user|>\n{instruction}</s>\n<|assistant|>\n{output}</s>"
        texts.append(text)

    return {"text": texts}

dataset = dataset.map(format_prompts, batched=True) # Apply formatting

# dataset = dataset.remove_columns(['instruction', 'input', 'output']) # Keep only formatted text

splits = dataset.train_test_split(test_size=0.4, seed=42)
train_split = splits["train"]
train_split = train_split.remove_columns(['instruction', 'input', 'output'])
test_split = splits["test"] # Keep test dataset with original columns for evaluation

# Before formatting:
# {
#     "instruction": "What are the three primary colors?",
#     "input": "",
#     "output": "The three primary colors are red, blue, and yellow."
# }
# {
#     "instruction": "Translate the following phrase into French.",
#     "input": "I love you.",
#     "output": "Je t'aime."
# }
#
# After formatting:
# {
#     "text": "<|system|>\nYou are a helpful AI assistant.</s>\n<|user|>\nWhat are the three primary colors?</s>\n<|assistant|>\nThe three primary colors are red, blue, and yellow.</s>"
# }
# {
#     "text": "<|system|>\nYou are a helpful AI assistant.</s>\n<|user|>\nTranslate the following phrase into French.\n\nI love you.</s>\n<|assistant|>\nJe t'aime.</s>"
# }
# Out:
# Map:   0%|          | 0/52002 [00:00<?, ? examples/s]

# %%
print(train_split)
print(train_split.shape)
print(test_split)
print(test_split.shape)
# Out:
# Dataset({
#     features: ['text'],
#     num_rows: 31201
# })
# (31201, 1)
# Dataset({
#     features: ['instruction', 'input', 'output', 'text'],
#     num_rows: 20801
# })
# (20801, 4)

# %% [markdown]
# Configure Training Arguments

# %%
# Training arguments optimized for TinyLlama
training_arguments = TrainingArguments(
    output_dir="./results",
    num_train_epochs=1,
    per_device_train_batch_size=4,  # Higher batch size for TinyLlama
    gradient_accumulation_steps=2,  # Effective batch size of 8
    optim="paged_adamw_32bit",
    save_steps=100,
    logging_steps=50,
    learning_rate=2e-4,
    weight_decay=0.01,  # Slight increase for regularization
    fp16=False, # T4-FP16
    bf16=False, # A100-BF16
    max_grad_norm=0.3,
    max_steps=-1,
    warmup_ratio=0.03,
    group_by_length=True,
    lr_scheduler_type="cosine",  # Better for longer training
    report_to="none",  # Disable wandb for simplicity
    push_to_hub=False,
    dataloader_pin_memory=False,
)

# %%
# Initialize the trainer
trainer = SFTTrainer(
    model=model,
    train_dataset=train_split,
    peft_config=peft_config,
    args=training_arguments,
    processing_class=tokenizer
)

# %% [markdown]
# Training the model

# %%
# Start training
print("Starting training...")
trainer.train()

# Save the fine-tuned LoRA adapter
trainer.save_model(new_model)
tokenizer.save_pretrained(new_model)

print(f"Model saved to {new_model}")
# Out:
# Starting training...
# {'loss': 1.3032, 'grad_norm': 1.329494833946228, 'learning_rate': 8.305084745762712e-05, 'num_tokens': 49212.0, 'mean_token_accuracy': 0.7049503976106644, 'epoch': 0.012818869375721062}
# {'loss': 1.0717, 'grad_norm': 1.2611113786697388, 'learning_rate': 0.00016779661016949154, 'num_tokens': 98965.0, 'mean_token_accuracy': 0.7398751503229142, 'epoch': 0.025637738751442124}
# {'loss': 1.008, 'grad_norm': 1.0375902652740479, 'learning_rate': 0.00019996686427563746, 'num_tokens': 145819.0, 'mean_token_accuracy': 0.7485605400800704, 'epoch': 0.038456608127163186}
# {'loss': 1.0153, 'grad_norm': 0.9698510766029358, 'learning_rate': 0.00019977384648529314, 'num_tokens': 193664.0, 'mean_token_accuracy': 0.7481109154224396, 'epoch': 0.05127547750288425}
# {'loss': 0.9865, 'grad_norm': 0.9542326927185059, 'learning_rate': 0.0001994088314905155, 'num_tokens': 241533.0, 'mean_token_accuracy': 0.755344632267952, 'epoch': 0.06409434687860531}
# {'loss': 0.999, 'grad_norm': 0.8574169278144836, 'learning_rate': 0.00019887244852993656, 'num_tokens': 289752.0, 'mean_token_accuracy': 0.7485885810852051, 'epoch': 0.07691321625432637}
# {'loss': 0.9747, 'grad_norm': 0.7764754891395569, 'learning_rate': 0.00019816562225839304, 'num_tokens': 336192.0, 'mean_token_accuracy': 0.7563365995883942, 'epoch': 0.08973208563004743}
# {'loss': 0.9805, 'grad_norm': 0.8205369114875793, 'learning_rate': 0.00019728957115294082, 'num_tokens': 381790.0, 'mean_token_accuracy': 0.7553783476352691, 'epoch': 0.1025509550057685}
# {'loss': 1.0127, 'grad_norm': 0.7329686284065247, 'learning_rate': 0.00019624580541235836, 'num_tokens': 430449.0, 'mean_token_accuracy': 0.7481054598093033, 'epoch': 0.11536982438148956}
# {'loss': 0.9724, 'grad_norm': 0.8790884017944336, 'learning_rate': 0.00019503612435375916, 'num_tokens': 478765.0, 'mean_token_accuracy': 0.7550992423295975, 'epoch': 0.12818869375721062}
# {'loss': 0.9618, 'grad_norm': 0.7776969075202942, 'learning_rate': 0.00019366261331080193, 'num_tokens': 528713.0, 'mean_token_accuracy': 0.7568381607532502, 'epoch': 0.14100756313293167}
# {'loss': 0.9704, 'grad_norm': 0.7650402188301086, 'learning_rate': 0.0001921276400388451, 'num_tokens': 576898.0, 'mean_token_accuracy': 0.7573644345998765, 'epoch': 0.15382643250865274}
# {'loss': 0.9564, 'grad_norm': 0.7159230709075928, 'learning_rate': 0.0001904338506332429, 'num_tokens': 625351.0, 'mean_token_accuracy': 0.7593917572498321, 'epoch': 0.1666453018843738}
# {'loss': 0.9454, 'grad_norm': 0.7235111594200134, 'learning_rate': 0.0001885841649678192, 'num_tokens': 672229.0, 'mean_token_accuracy': 0.7619217222929001, 'epoch': 0.17946417126009487}
# {'loss': 0.9719, 'grad_norm': 0.6492111086845398, 'learning_rate': 0.00018658177166138286, 'num_tokens': 721630.0, 'mean_token_accuracy': 0.7532838875055313, 'epoch': 0.19228304063581592}
# {'loss': 0.9648, 'grad_norm': 0.6694628000259399, 'learning_rate': 0.00018443012258096135, 'num_tokens': 769505.0, 'mean_token_accuracy': 0.7575322872400284, 'epoch': 0.205101910011537}
# {'loss': 0.9575, 'grad_norm': 0.6684131622314453, 'learning_rate': 0.00018213292689122843, 'num_tokens': 817297.0, 'mean_token_accuracy': 0.7583100426197052, 'epoch': 0.21792077938725804}
# {'loss': 0.9463, 'grad_norm': 0.7336435914039612, 'learning_rate': 0.00017969414466038422, 'num_tokens': 865274.0, 'mean_token_accuracy': 0.7624660462141037, 'epoch': 0.23073964876297912}
# {'loss': 0.9569, 'grad_norm': 0.6895385384559631, 'learning_rate': 0.00017711798003350993, 'num_tokens': 911154.0, 'mean_token_accuracy': 0.7592872023582459, 'epoch': 0.24355851813870016}
# {'loss': 0.9589, 'grad_norm': 0.7749115228652954, 'learning_rate': 0.00017440887398516535, 'num_tokens': 957114.0, 'mean_token_accuracy': 0.7604171669483185, 'epoch': 0.25637738751442124}
# {'loss': 0.9565, 'grad_norm': 0.740479588508606, 'learning_rate': 0.0001715714966637235, 'num_tokens': 1003808.0, 'mean_token_accuracy': 0.7590160316228867, 'epoch': 0.2691962568901423}
# {'loss': 0.9668, 'grad_norm': 0.6922715902328491, 'learning_rate': 0.0001686107393406388, 'num_tokens': 1052527.0, 'mean_token_accuracy': 0.7557382994890213, 'epoch': 0.28201512626586334}
# {'loss': 0.9486, 'grad_norm': 0.7008938789367676, 'learning_rate': 0.00016553170597852782, 'num_tokens': 1099337.0, 'mean_token_accuracy': 0.7577567875385285, 'epoch': 0.2948339956415844}
# {'loss': 0.9553, 'grad_norm': 0.6705600023269653, 'learning_rate': 0.0001623397044325981, 'num_tokens': 1147365.0, 'mean_token_accuracy': 0.7591687697172165, 'epoch': 0.3076528650173055}
# {'loss': 0.9568, 'grad_norm': 0.6955867409706116, 'learning_rate': 0.00015904023730059228, 'num_tokens': 1194207.0, 'mean_token_accuracy': 0.7587775683403015, 'epoch': 0.3204717343930265}
# {'loss': 0.971, 'grad_norm': 0.660975456237793, 'learning_rate': 0.00015563899243702152, 'num_tokens': 1241991.0, 'mean_token_accuracy': 0.7565334504842758, 'epoch': 0.3332906037687476}
# {'loss': 0.9353, 'grad_norm': 0.6901178359985352, 'learning_rate': 0.00015214183314804, 'num_tokens': 1290655.0, 'mean_token_accuracy': 0.7643813109397888, 'epoch': 0.34610947314446866}
# {'loss': 0.9725, 'grad_norm': 0.6133720874786377, 'learning_rate': 0.00014855478808386378, 'num_tokens': 1341485.0, 'mean_token_accuracy': 0.7535303121805191, 'epoch': 0.35892834252018974}
# {'loss': 0.9646, 'grad_norm': 0.7135183215141296, 'learning_rate': 0.00014488404084615742, 'num_tokens': 1390242.0, 'mean_token_accuracy': 0.7576644766330719, 'epoch': 0.37174721189591076}
# {'loss': 0.9605, 'grad_norm': 0.6672405004501343, 'learning_rate': 0.000141135919328305, 'num_tokens': 1440488.0, 'mean_token_accuracy': 0.7579549884796143, 'epoch': 0.38456608127163183}
# {'loss': 0.9737, 'grad_norm': 0.6721850037574768, 'learning_rate': 0.00013731688480694005, 'num_tokens': 1489034.0, 'mean_token_accuracy': 0.7546728408336639, 'epoch': 0.3973849506473529}
# {'loss': 0.9514, 'grad_norm': 0.8045121431350708, 'learning_rate': 0.0001334335208035409, 'num_tokens': 1536420.0, 'mean_token_accuracy': 0.7578625845909118, 'epoch': 0.410203820023074}
# {'loss': 0.9622, 'grad_norm': 0.6373170018196106, 'learning_rate': 0.00012949252173529124, 'num_tokens': 1584059.0, 'mean_token_accuracy': 0.7579291427135467, 'epoch': 0.423022689398795}
# {'loss': 0.9564, 'grad_norm': 0.730643093585968, 'learning_rate': 0.00012550068137477056, 'num_tokens': 1631589.0, 'mean_token_accuracy': 0.7602619004249572, 'epoch': 0.4358415587745161}
# {'loss': 0.9379, 'grad_norm': 0.7384824752807617, 'learning_rate': 0.00012146488113836945, 'num_tokens': 1679305.0, 'mean_token_accuracy': 0.7620511215925216, 'epoch': 0.44866042815023716}
# {'loss': 0.9582, 'grad_norm': 0.6493794322013855, 'learning_rate': 0.0001173920782236178, 'num_tokens': 1726632.0, 'mean_token_accuracy': 0.7599928748607635, 'epoch': 0.46147929752595823}
# {'loss': 0.962, 'grad_norm': 0.6944906115531921, 'learning_rate': 0.00011328929361587617, 'num_tokens': 1775844.0, 'mean_token_accuracy': 0.7561837196350097, 'epoch': 0.47429816690167925}
# {'loss': 0.9435, 'grad_norm': 0.7072182297706604, 'learning_rate': 0.0001091635999850655, 'num_tokens': 1826603.0, 'mean_token_accuracy': 0.7599777203798294, 'epoch': 0.48711703627740033}
# {'loss': 0.9637, 'grad_norm': 0.6998180150985718, 'learning_rate': 0.00010502210949329873, 'num_tokens': 1876360.0, 'mean_token_accuracy': 0.7534053379297256, 'epoch': 0.4999359056531214}
# {'loss': 0.9325, 'grad_norm': 0.6659212708473206, 'learning_rate': 0.00010087196153443378, 'num_tokens': 1921972.0, 'mean_token_accuracy': 0.7642204058170319, 'epoch': 0.5127547750288425}
# {'loss': 0.9405, 'grad_norm': 0.6572647094726562, 'learning_rate': 9.672031042668189e-05, 'num_tokens': 1971424.0, 'mean_token_accuracy': 0.7612730294466019, 'epoch': 0.5255736444045636}
# {'loss': 0.9674, 'grad_norm': 0.7317245006561279, 'learning_rate': 9.257431307948836e-05, 'num_tokens': 2020448.0, 'mean_token_accuracy': 0.7571049135923386, 'epoch': 0.5383925137802846}
# {'loss': 0.9469, 'grad_norm': 0.7033036947250366, 'learning_rate': 8.844111665594687e-05, 'num_tokens': 2069849.0, 'mean_token_accuracy': 0.7617075836658478, 'epoch': 0.5512113831560056}
# {'loss': 0.939, 'grad_norm': 0.7091073393821716, 'learning_rate': 8.43278462520145e-05, 'num_tokens': 2116314.0, 'mean_token_accuracy': 0.7648102730512619, 'epoch': 0.5640302525317267}
# {'loss': 0.9133, 'grad_norm': 1.1392719745635986, 'learning_rate': 8.024159261376837e-05, 'num_tokens': 2162986.0, 'mean_token_accuracy': 0.7650499629974366, 'epoch': 0.5768491219074477}
# {'loss': 0.9484, 'grad_norm': 0.7870667576789856, 'learning_rate': 7.618939991387636e-05, 'num_tokens': 2210203.0, 'mean_token_accuracy': 0.7601718866825103, 'epoch': 0.5896679912831688}
# {'loss': 0.9581, 'grad_norm': 0.6655616760253906, 'learning_rate': 7.217825360835473e-05, 'num_tokens': 2258386.0, 'mean_token_accuracy': 0.7589016675949096, 'epoch': 0.6024868606588899}
# {'loss': 0.9479, 'grad_norm': 0.7018828392028809, 'learning_rate': 6.821506839454594e-05, 'num_tokens': 2305610.0, 'mean_token_accuracy': 0.7592511773109436, 'epoch': 0.615305730034611}
# {'loss': 0.9416, 'grad_norm': 0.758185625076294, 'learning_rate': 6.430667629107439e-05, 'num_tokens': 2354359.0, 'mean_token_accuracy': 0.762050449848175, 'epoch': 0.628124599410332}
# {'loss': 0.9588, 'grad_norm': 0.651826798915863, 'learning_rate': 6.045981486033053e-05, 'num_tokens': 2402307.0, 'mean_token_accuracy': 0.7567390269041061, 'epoch': 0.640943468786053}
# {'loss': 0.948, 'grad_norm': 0.6742005348205566, 'learning_rate': 5.668111559378471e-05, 'num_tokens': 2450337.0, 'mean_token_accuracy': 0.7603898406028747, 'epoch': 0.6537623381617741}
# {'loss': 0.9277, 'grad_norm': 0.7398866415023804, 'learning_rate': 5.2977092480153734e-05, 'num_tokens': 2500033.0, 'mean_token_accuracy': 0.762970889210701, 'epoch': 0.6665812075374952}
# {'loss': 0.9072, 'grad_norm': 0.6741374731063843, 'learning_rate': 4.9354130776127105e-05, 'num_tokens': 2544402.0, 'mean_token_accuracy': 0.771298286318779, 'epoch': 0.6794000769132162}
# {'loss': 0.9454, 'grad_norm': 0.6810861825942993, 'learning_rate': 4.5818475999010214e-05, 'num_tokens': 2591993.0, 'mean_token_accuracy': 0.7583968710899353, 'epoch': 0.6922189462889373}
# {'loss': 0.9124, 'grad_norm': 0.6910616755485535, 'learning_rate': 4.237622316026091e-05, 'num_tokens': 2638910.0, 'mean_token_accuracy': 0.769250825047493, 'epoch': 0.7050378156646584}
# {'loss': 0.9309, 'grad_norm': 0.818398654460907, 'learning_rate': 3.9033306258477634e-05, 'num_tokens': 2685003.0, 'mean_token_accuracy': 0.7650199192762375, 'epoch': 0.7178566850403795}
# {'loss': 0.9528, 'grad_norm': 0.6437812447547913, 'learning_rate': 3.579548804995392e-05, 'num_tokens': 2735469.0, 'mean_token_accuracy': 0.7588924729824066, 'epoch': 0.7306755544161005}
# {'loss': 0.9494, 'grad_norm': 0.7238903641700745, 'learning_rate': 3.2668350114431844e-05, 'num_tokens': 2783718.0, 'mean_token_accuracy': 0.7613842928409577, 'epoch': 0.7434944237918215}
# {'loss': 0.9551, 'grad_norm': 0.6987308263778687, 'learning_rate': 2.965728323318061e-05, 'num_tokens': 2832678.0, 'mean_token_accuracy': 0.7590433138608933, 'epoch': 0.7563132931675426}
# {'loss': 0.9422, 'grad_norm': 0.6976768970489502, 'learning_rate': 2.676747809598691e-05, 'num_tokens': 2879239.0, 'mean_token_accuracy': 0.7587924015522003, 'epoch': 0.7691321625432637}
# {'loss': 0.9363, 'grad_norm': 0.7885808348655701, 'learning_rate': 2.4003916353077416e-05, 'num_tokens': 2928611.0, 'mean_token_accuracy': 0.7611880362033844, 'epoch': 0.7819510319189847}
# {'loss': 0.93, 'grad_norm': 0.6673067212104797, 'learning_rate': 2.1371362027398036e-05, 'num_tokens': 2977319.0, 'mean_token_accuracy': 0.7620707780122757, 'epoch': 0.7947699012947058}
# {'loss': 0.9498, 'grad_norm': 0.7037846446037292, 'learning_rate': 1.8874353302054725e-05, 'num_tokens': 3027656.0, 'mean_token_accuracy': 0.7556254589557647, 'epoch': 0.8075887706704269}
# {'loss': 0.9153, 'grad_norm': 0.7642326354980469, 'learning_rate': 1.65171946970729e-05, 'num_tokens': 3074734.0, 'mean_token_accuracy': 0.7667620861530304, 'epoch': 0.820407640046148}
# {'loss': 0.951, 'grad_norm': 0.7576822638511658, 'learning_rate': 1.4303949648961612e-05, 'num_tokens': 3123867.0, 'mean_token_accuracy': 0.759774643778801, 'epoch': 0.833226509421869}
# {'loss': 0.9253, 'grad_norm': 0.6895357370376587, 'learning_rate': 1.2238433505874847e-05, 'num_tokens': 3173190.0, 'mean_token_accuracy': 0.7619551736116409, 'epoch': 0.84604537879759}
# {'loss': 0.9611, 'grad_norm': 0.7129296064376831, 'learning_rate': 1.032420695044477e-05, 'num_tokens': 3223990.0, 'mean_token_accuracy': 0.7564905607700347, 'epoch': 0.8588642481733111}
# {'loss': 0.9494, 'grad_norm': 0.8852118253707886, 'learning_rate': 8.564569861625427e-06, 'num_tokens': 3271179.0, 'mean_token_accuracy': 0.7599968767166138, 'epoch': 0.8716831175490322}
# {'loss': 0.9283, 'grad_norm': 0.6750211119651794, 'learning_rate': 6.962555626128486e-06, 'num_tokens': 3319854.0, 'mean_token_accuracy': 0.7640902370214462, 'epoch': 0.8845019869247532}
# {'loss': 0.9389, 'grad_norm': 0.63141930103302, 'learning_rate': 5.5209259092567245e-06, 'num_tokens': 3369790.0, 'mean_token_accuracy': 0.7639960604906082, 'epoch': 0.8973208563004743}
# {'loss': 0.9507, 'grad_norm': 0.635820209980011, 'learning_rate': 4.242165894150485e-06, 'num_tokens': 3419479.0, 'mean_token_accuracy': 0.7585398596525192, 'epoch': 0.9101397256761954}
# {'loss': 0.9301, 'grad_norm': 0.7857735753059387, 'learning_rate': 3.128479997653333e-06, 'num_tokens': 3466294.0, 'mean_token_accuracy': 0.7635109573602676, 'epoch': 0.9229585950519165}
# {'loss': 0.9227, 'grad_norm': 0.7258777022361755, 'learning_rate': 2.1817880701825887e-06, 'num_tokens': 3515437.0, 'mean_token_accuracy': 0.7634944611787796, 'epoch': 0.9357774644276374}
# {'loss': 0.966, 'grad_norm': 0.6815881133079529, 'learning_rate': 1.4037220861556233e-06, 'num_tokens': 3567346.0, 'mean_token_accuracy': 0.7555334591865539, 'epoch': 0.9485963338033585}
# {'loss': 0.9687, 'grad_norm': 0.7296487092971802, 'learning_rate': 7.956233306769978e-07, 'num_tokens': 3616915.0, 'mean_token_accuracy': 0.7551604896783829, 'epoch': 0.9614152031790796}
# {'loss': 0.9263, 'grad_norm': 0.6210461258888245, 'learning_rate': 3.585400873365341e-07, 'num_tokens': 3664773.0, 'mean_token_accuracy': 0.7630509430170059, 'epoch': 0.9742340725548007}
# {'loss': 0.946, 'grad_norm': 0.6304285526275635, 'learning_rate': 9.32258311039269e-08, 'num_tokens': 3713742.0, 'mean_token_accuracy': 0.760819662809372, 'epoch': 0.9870529419305217}
# {'loss': 0.9297, 'grad_norm': 0.7896788716316223, 'learning_rate': 1.3792943545087865e-10, 'num_tokens': 3763658.0, 'mean_token_accuracy': 0.762907350063324, 'epoch': 0.9998718113062428}
# {'train_runtime': 4607.5098, 'train_samples_per_second': 6.772, 'train_steps_per_second': 0.847, 'train_loss': 0.9590513291526409, 'num_tokens': 3763989.0, 'mean_token_accuracy': 0.699999988079071, 'epoch': 1.0}
# Model saved to tinyllama-1.1b-lora-finetuned

# %%
# # Test the fine-tuned model
# from peft import PeftModel

# # Load base model for inference
# base_model = AutoModelForCausalLM.from_pretrained(
#     model_name,
#     torch_dtype=torch.float16,
#     device_map="auto",
#     trust_remote_code=True
# )

# # Load the fine-tuned LoRA adapter
# model = PeftModel.from_pretrained(base_model, new_model)
# # It's designed to load a base pre-trained model and then inject or load the trained PEFT adapters, here LoRA adapters

# # Load tokenizer
# tokenizer = AutoTokenizer.from_pretrained(model_name, trust_remote_code=True)
# tokenizer.pad_token = tokenizer.eos_token
# tokenizer.padding_side = "right"

# # Test inference with ChatML format
# def generate_response(prompt):
#     # Format using ChatML template for TinyLlama
#     formatted_prompt = f"<|system|>\nYou are a helpful AI assistant.</s>\n<|user|>\n{prompt}</s>\n<|assistant|>\n"

#     inputs = tokenizer(formatted_prompt, return_tensors="pt").to(model.device)

#     with torch.no_grad():
#         outputs = model.generate(
#             **inputs,
#             max_new_tokens=256,
#             temperature=0.7,
#             do_sample=True,
#             top_k=50,
#             top_p=0.95,
#             pad_token_id=tokenizer.eos_token_id,
#             eos_token_id=tokenizer.eos_token_id,
#         )

#     # Decode and extract only the assistant's response
#     full_response = tokenizer.decode(outputs[0], skip_special_tokens=True)
#     assistant_response = full_response.split("<|assistant|>")[-1].strip()
#     return assistant_response

# # Test the model
# test_prompts = [
#     "Explain machine learning in simple terms.",
#     "Write a short story about a robot learning to paint.",
#     "What are the benefits of renewable energy?",
# ]

# for prompt in test_prompts:
#     print(f"\nPrompt: {prompt}")
#     response = generate_response(prompt)
#     print(f"Response: {response}")
#     print("-" * 50)

# %% [markdown]
# Testing the model

# %%
# Test the fine-tuned model
from peft import PeftModel

# Load tokenizer
tokenizer = AutoTokenizer.from_pretrained(model_name, trust_remote_code=True)
tokenizer.pad_token = tokenizer.eos_token
tokenizer.padding_side = "right"

# Generation parameters
gen_kwargs = dict(
    max_new_tokens=256,
    temperature=0.7,
    top_k=50,
    top_p=0.95,
    do_sample=True,
    pad_token_id=tokenizer.eos_token_id,
    eos_token_id=tokenizer.eos_token_id,
)

# ChatML formatting
def build_chatml(user_msg, system_msg="You are a helpful AI assistant."):
    return (
        f"<|system|>\n{system_msg}</s>\n"
        f"<|user|>\n{user_msg}</s>\n"
        f"<|assistant|>\n"
    )

# Helper: generate one response from a given model
def generate_with_model(model, prompt):
    formatted = build_chatml(prompt)
    inputs = tokenizer(formatted, return_tensors="pt").to(next(model.parameters()).device)
    with torch.no_grad():
        outputs = model.generate(**inputs, **gen_kwargs)
    decoded = tokenizer.decode(outputs[0], skip_special_tokens=True)
    # Extract assistant part
    if "<|assistant|>" in decoded:
        return decoded.split("<|assistant|>")[-1].strip()
    return decoded.strip()

# Load BASE model (wo LoRA)
base_model = AutoModelForCausalLM.from_pretrained(
    model_name,
    torch_dtype=torch.float16 if torch.cuda.is_available() else torch.float32,
    device_map="auto",
    trust_remote_code=True,
    low_cpu_mem_usage=True,
)
base_model.eval()

# Load BASE + LoRA adapter
lora_model = AutoModelForCausalLM.from_pretrained(
    model_name,
    torch_dtype=torch.float16 if torch.cuda.is_available() else torch.float32,
    device_map="auto",
    trust_remote_code=True,
    low_cpu_mem_usage=True,
)
lora_model = PeftModel.from_pretrained(lora_model, new_model)
lora_model.eval()

# Test prompts
test_prompts = [
    "Explain what is machine learning in simple words.",
    "What are the four main types of energy resources?",
]

# Compare outputs
print("=== Testing Base TinyLlama vs TinyLlama + LoRA ===")
for i, prompt in enumerate(test_prompts, 1):
    print(f"\n[{i}] Prompt: {prompt}")

    base_resp = generate_with_model(base_model, prompt)
    print("\n-- Base TinyLlama --")
    print(base_resp)

    lora_resp = generate_with_model(lora_model, prompt)
    print("\n-- TinyLlama + LoRA --")
    print(lora_resp)

    print("\n" + "-" * 50)
# Out:
# === Testing Base TinyLlama vs TinyLlama + LoRA ===
#
# [1] Prompt: Explain what is machine learning in simple words.
#
# -- Base TinyLlama --
# Machine learning is the process of teaching computers to perform tasks without being explicitly programmed. It involves the development of algorithms that can learn from data and improve their performance over time. Machine learning can be used in various applications, including:
#
# 1. Image and video recognition: Machine learning algorithms can be trained to identify objects, people, and objects in images and videos.
#
# 2. Natural language processing: Machine learning can be used to analyze text and understand its meaning.
#
# 3. Machine translation: Machine learning can be used to improve the accuracy and speed of machine translation.
#
# 4. Predictive maintenance: Machine learning can be used to identify potential issues in machinery and predict when maintenance is needed.
#
# 5. Fraud detection: Machine learning can be used to detect fraudulent transactions and identify potential fraudsters.
#
# 6. Predictive analytics: Machine learning can be used to predict outcomes based on historical data.
#
# 7. Customer segmentation: Machine learning can be used to segment customers based on their behavior and preferences, allowing businesses to offer tailored products and services.
#
# Overall, machine learning is a powerful tool that can help organizations improve their operations, increase efficiency, and drive
#
# -- TinyLlama + LoRA --
# Machine learning is a field of artificial intelligence that involves the use of algorithms and data to learn and improve from data without being programmed. It enables computers to learn from their interactions with humans and the environment around them, improving their performance over time.
#
# The basic idea behind machine learning is to develop algorithms that can analyze large amounts of data and make predictions based on it. Machine learning algorithms use statistical models, decision trees, and neural networks to solve problems that require a lot of data.
#
# One example of machine learning is recommender systems, where a machine recommends items or content based on the user's past actions and preferences. Another example is image recognition, where a machine can recognize images based on their features and classify them into categories.
#
# Machine learning is a powerful tool in many industries, including finance, healthcare, e-commerce, and customer service. It has helped businesses to improve their decision-making processes, provide personalized experiences, and optimize their operations.
#
# In summary, machine learning is a powerful tool that helps computers to learn from data and improve their performance over time.
#
# --------------------------------------------------
#
# [2] Prompt: What are the four main types of energy resources?
#
# -- Base TinyLlama --
# 1. Solar Energy: This is the most commonly available and abundant type of energy resource. It comes from the sun and can be used to generate electricity, heat, and cooling.
#
# 2. Hydro Energy: Hydroelectricity is generated from the movement of water. It can be harnessed from rivers, lakes, and dams.
#
# 3. Geothermal Energy: Geothermal energy is generated from the earth's heat. It is used to produce hot water or steam for heating, power generation, or industrial processes.
#
# 4. Biomass Energy: Biomass energy is generated from organic matter, such as wood, agricultural waste, and animal manure. It can be used to generate heat, electricity, or both.
#
# 5. Nuclear Energy: Nuclear energy involves the use of nuclear fission to generate electricity. It is considered a clean and sustainable source of energy.
#
# 6. Wind Energy: Wind energy involves the use of wind turbines to generate electricity. It is an eco-friendly and renewable source of energy.
#
# 7. Biogas Energy: Biogas energy
#
# -- TinyLlama + LoRA --
# There are four main types of energy resources:
#
# 1. Renewable Energy Resources: These are resources that can be replenished without depletion, such as solar, wind, hydro, geothermal, and biomass.
#
# 2. Non-Renewable Energy Resources: These are resources that cannot be replenished, such as coal, oil, natural gas, and nuclear power.
#
# 3. Carbon-Free Energy Resources: These are energy resources that do not produce any carbon emissions, such as nuclear energy, geothermal power, and hydrogen fuel cells.
#
# 4. Nuclear Energy Resources: These are energy resources generated by the splitting of atomic nuclei.
#
# Note: Non-renewable and carbon-free energy resources are essential for maintaining the global energy system and reducing greenhouse gas emissions.
#
# --------------------------------------------------

# %%
# Merge LoRA weights with base model for deployment
merged_model = model.merge_and_unload()

# Save the merged model
merged_model.save_pretrained("tinyllama-1.1b-merged")
tokenizer.save_pretrained("tinyllama-1.1b-merged")

print("Merged model saved!")

# Push to Hugging Face Hub
# merged_model.push_to_hub("your-username/tinyllama-1.1b-finetuned")
# tokenizer.push_to_hub("your-username/tinyllama-1.1b-finetuned")
# Out:
# Merged model saved!

# %%
# Save the merged model in MyDrive
save_dir = "/content/drive/MyDrive/Colab Notebooks/models/tinyllama-1.1b-merged"
os.makedirs(save_dir, exist_ok=True)
merged_model.save_pretrained(save_dir)
tokenizer.save_pretrained(save_dir)

print("Merged model saved in MyDrive!")
# Out:
# Merged model saved in MyDrive!

# %% [markdown]
#  Evaluation Metrics

# %%
# ===== Load Pre-trained Evaluation Metrics =====
print("Loading evaluation metrics...")
perplexity_metric = evaluate.load("perplexity", module_type="metric")
bleu_metric = evaluate.load("bleu")
rouge_metric = evaluate.load("rouge")

# ===== Model Setup =====
model_name = "TinyLlama/TinyLlama-1.1B-Chat-v1.0"
adapter_dir = "tinyllama-1.1b-lora-finetuned"
merged_dir = "/content/drive/MyDrive/Colab Notebooks/models/tinyllama-1.1b-merged"

# Load tokenizer
tokenizer = AutoTokenizer.from_pretrained(merged_dir, trust_remote_code=True)
tokenizer.pad_token = tokenizer.eos_token
tokenizer.padding_side = "right"

# Generation parameters
gen_kwargs = {
    "max_new_tokens": 256,
    "temperature": 0.7,
    "top_k": 50,
    "top_p": 0.95,
    "do_sample": True,
    "pad_token_id": tokenizer.eos_token_id,
    "eos_token_id": tokenizer.eos_token_id,
}

def build_chatml(user_msg, system_msg="You are a helpful AI assistant."):
    return f"<|system|>\n{system_msg}</s>\n<|user|>\n{user_msg}</s>\n<|assistant|>\n"

def generate_with_model(model, prompt):
    formatted = build_chatml(prompt)
    inputs = tokenizer(formatted, return_tensors="pt").to(next(model.parameters()).device)
    with torch.no_grad():
        outputs = model.generate(**inputs, **gen_kwargs)
    decoded = tokenizer.decode(outputs[0], skip_special_tokens=True)
    if "<|assistant|>" in decoded:
        return decoded.split("<|assistant|>")[-1].strip()
    return decoded.strip()

# ===== Evaluation Functions =====
def evaluate_model_comprehensive(model, test_dataset, model_name_str, batch_size=100):
    """
    Evaluate model using Hugging Face Evaluate library metrics
    """
    print(f"\n=== Evaluating {model_name_str} ===")

    # Prepare test data
    test_prompts = []
    references = []
    predictions = []

    # Create prompts and references from test dataset
    for item in test_dataset:
        if item["input"]:
            prompt = f"{item['instruction']}\n\n{item['input']}"
        else:
            prompt = item["instruction"]
        test_prompts.append(prompt)
        references.append(item["output"])

    # Generate predictions in batches
    print(f"Generating predictions for {len(test_prompts)} samples...")
    for i in tqdm(range(0, len(test_prompts), batch_size), desc="Generating"):
        batch_prompts = test_prompts[i:i+batch_size]
        batch_preds = []

        # for prompt in batch_prompts:
        for j, prompt in tqdm(enumerate(batch_prompts, 1), desc="Predicting"):
            # print(f"\nPrompt {j}: {prompt}")
            pred = generate_with_model(model, prompt)
            # print(f"\nPred {j}: {pred}")
            batch_preds.append(pred)

        predictions.extend(batch_preds)

    # 1. PERPLEXITY using Hugging Face Evaluate
    print("Computing perplexity...")

    # For perplexity, we need the full formatted text sequences
    formatted_sequences = []
    for prompt, ref in zip(test_prompts, references):
        formatted_text = build_chatml(prompt) + ref + "</s>"
        formatted_sequences.append(formatted_text)

    # Use a subset for perplexity (it's computationally expensive)
    ppl_subset_size = min(1000, len(formatted_sequences))
    ppl_sequences = formatted_sequences[:ppl_subset_size]

    try:
        ppl_results = perplexity_metric.compute(
            predictions=ppl_sequences,
            model_id=merged_dir,  # Use base model name for tokenizer
            batch_size=16,
            add_start_token=False
        )
        perplexity_score = ppl_results["mean_perplexity"]
    except Exception as e:
        print(f"Perplexity computation failed: {e}")
        perplexity_score = float('inf')

    print("Perplexity computed!")

    # 2. BLEU Score
    print("Computing BLEU...")
    bleu_results = bleu_metric.compute(
        predictions=predictions,
        references=[[ref] for ref in references]  # BLEU expects list of lists
    )

    print("BLEU computed!")

    # 3. ROUGE Scores
    print("Computing ROUGE...")
    rouge_results = rouge_metric.compute(
        predictions=predictions,
        references=references
    )

    print("ROUGE computed!")

    return {
        "model_name": model_name_str,
        "perplexity": perplexity_score,
        "bleu": bleu_results["bleu"] * 100,  # Convert to percentage
        "rouge1": rouge_results["rouge1"] * 100,
        "rouge2": rouge_results["rouge2"] * 100,
        "rougeL": rouge_results["rougeL"] * 100,
        "predictions": predictions[:5],  # First 5 for inspection
        "references": references[:5],
        "sample_size": len(predictions),
        "perplexity_sample_size": ppl_subset_size
    }

# ===== Load Models =====
# print("Loading base TinyLlama model...")
# base_model = AutoModelForCausalLM.from_pretrained(
#     model_name,
#     torch_dtype=torch.float16 if torch.cuda.is_available() else torch.float32,
#     device_map="auto",
#     trust_remote_code=True,
#     low_cpu_mem_usage=True,
# )
# base_model.eval()

print("Loading TinyLlama + LoRA model...")
lora_model = AutoModelForCausalLM.from_pretrained(
    merged_dir,
    torch_dtype=torch.float16 if torch.cuda.is_available() else torch.float32,
    device_map="auto",
    trust_remote_code=True,
    low_cpu_mem_usage=True,
)
# lora_model = PeftModel.from_pretrained(lora_model, adapter_dir)
lora_model.eval()

# ===== Run Comprehensive Evaluation =====
print("Starting comprehensive evaluation on test dataset...")

# Randomly sample 1000 examples from the test set
random.seed(42)
sampled_test = test_split.shuffle(seed=42).select(range(min(1000, len(test_split))))

# Evaluate base model
# base_results = evaluate_model_comprehensive(
#     base_model,
#     sampled_test,
#     "Base TinyLlama",
#     batch_size=50  # Adjust based on your GPU memory
# )

# Evaluate LoRA model
lora_results = evaluate_model_comprehensive(
    lora_model,
    sampled_test,
    "TinyLlama + LoRA",
    batch_size=50
)
# Out:
# Loading evaluation metrics...
# Loading TinyLlama + LoRA model...
# Starting comprehensive evaluation on test dataset...
#
# === Evaluating TinyLlama + LoRA ===
# Generating predictions for 1000 samples...
# Generating:   0%|          | 0/20 [00:00<?, ?it/s]
# Predicting: 0it [00:00, ?it/s]
# Predicting: 1it [00:03,  3.23s/it]
# Predicting: 2it [00:12,  6.73s/it]
# Predicting: 3it [00:22,  8.25s/it]
# Predicting: 4it [00:46, 14.37s/it]
# Predicting: 5it [00:47,  9.47s/it]
# Predicting: 6it [00:47,  6.44s/it]
# Predicting: 7it [00:49,  4.81s/it]
# Predicting: 8it [00:53,  4.73s/it]
# Predicting: 9it [01:05,  6.90s/it]
# Predicting: 10it [01:06,  5.28s/it]
# Predicting: 11it [01:12,  5.43s/it]
# Predicting: 12it [01:24,  7.47s/it]
# Predicting: 13it [01:30,  6.91s/it]
# Predicting: 14it [01:42,  8.48s/it]
# Predicting: 15it [01:54,  9.53s/it]
# Predicting: 16it [01:54,  6.80s/it]
# Predicting: 17it [02:06,  8.37s/it]
# Predicting: 18it [02:07,  5.93s/it]
# Predicting: 19it [02:08,  4.57s/it]
# Predicting: 20it [02:11,  4.09s/it]
# Predicting: 21it [02:16,  4.19s/it]
# Predicting: 22it [02:19,  3.88s/it]
# Predicting: 23it [02:21,  3.48s/it]
# Predicting: 24it [02:22,  2.67s/it]
# Predicting: 25it [02:33,  5.21s/it]
# Predicting: 26it [02:43,  6.66s/it]
# Predicting: 27it [02:55,  8.24s/it]
# Predicting: 28it [02:56,  6.10s/it]
# Predicting: 29it [03:03,  6.30s/it]
# Predicting: 30it [03:15,  7.90s/it]
# Predicting: 31it [03:17,  6.16s/it]
# Predicting: 32it [03:18,  4.59s/it]
# Predicting: 33it [03:29,  6.71s/it]
# Predicting: 34it [03:33,  5.83s/it]
# Predicting: 35it [03:45,  7.71s/it]
# Predicting: 36it [03:46,  5.56s/it]
# Predicting: 37it [03:58,  7.47s/it]
# Predicting: 38it [04:06,  7.62s/it]
# Predicting: 39it [04:15,  8.12s/it]
# Predicting: 40it [04:19,  6.88s/it]
# Predicting: 41it [04:21,  5.36s/it]
# Predicting: 42it [04:33,  7.32s/it]
# Predicting: 43it [04:44,  8.68s/it]
# Predicting: 44it [04:45,  6.37s/it]
# Predicting: 45it [04:48,  5.29s/it]
# Predicting: 46it [04:52,  4.77s/it]
# Predicting: 47it [05:04,  6.91s/it]
# Predicting: 48it [05:10,  6.80s/it]
# Predicting: 49it [05:15,  6.34s/it]
# Predicting: 50it [05:23,  6.46s/it]
# Generating:   5%|▌         | 1/20 [05:23<1:42:20, 323.20s/it]
# Predicting: 0it [00:00, ?it/s]
# Predicting: 1it [00:03,  3.50s/it]
# Predicting: 2it [00:06,  3.30s/it]
# Predicting: 3it [00:13,  4.84s/it]
# Predicting: 4it [00:13,  3.04s/it]
# Predicting: 5it [00:13,  2.03s/it]
# Predicting: 6it [00:20,  3.74s/it]
# Predicting: 7it [00:21,  2.66s/it]
# Predicting: 8it [00:33,  5.63s/it]
# Predicting: 9it [00:34,  4.24s/it]
# Predicting: 10it [00:46,  6.67s/it]
# Predicting: 11it [00:58,  8.35s/it]
# Predicting: 12it [00:59,  5.96s/it]
# Predicting: 13it [01:11,  7.79s/it]
# Predicting: 14it [01:13,  6.00s/it]
# Predicting: 15it [01:14,  4.48s/it]
# Predicting: 16it [01:20,  4.99s/it]
# Predicting: 17it [01:21,  3.95s/it]
# Predicting: 18it [01:29,  5.01s/it]
# Predicting: 19it [01:29,  3.66s/it]
# Predicting: 20it [01:38,  5.05s/it]
# Predicting: 21it [01:38,  3.64s/it]
# Predicting: 22it [01:38,  2.70s/it]
# Predicting: 23it [01:50,  5.28s/it]
# Predicting: 24it [01:55,  5.25s/it]
# Predicting: 25it [01:55,  3.76s/it]
# Predicting: 26it [02:01,  4.24s/it]
# Predicting: 27it [02:10,  5.78s/it]
# Predicting: 28it [02:11,  4.27s/it]
# Predicting: 29it [02:11,  3.16s/it]
# Predicting: 30it [02:20,  4.98s/it]
# Predicting: 31it [02:21,  3.65s/it]
# Predicting: 32it [02:22,  2.97s/it]
# Predicting: 33it [02:34,  5.68s/it]
# Predicting: 34it [02:35,  4.24s/it]
# Predicting: 35it [02:47,  6.57s/it]
# Predicting: 36it [02:48,  4.72s/it]
# Predicting: 37it [02:48,  3.43s/it]
# Predicting: 38it [02:49,  2.59s/it]
# Predicting: 39it [02:58,  4.66s/it]
# Predicting: 40it [03:01,  4.12s/it]
# Predicting: 41it [03:13,  6.55s/it]
# Predicting: 42it [03:25,  8.23s/it]
# Predicting: 43it [03:32,  7.81s/it]
# Predicting: 44it [03:33,  5.76s/it]
# Predicting: 45it [03:41,  6.22s/it]
# Predicting: 46it [03:53,  7.99s/it]
# Predicting: 47it [03:56,  6.73s/it]
# Predicting: 48it [03:59,  5.43s/it]
# Predicting: 49it [04:11,  7.42s/it]
# Predicting: 50it [04:12,  5.04s/it]
# Generating:  10%|█         | 2/20 [09:35<1:24:23, 281.32s/it]
# Predicting: 0it [00:00, ?it/s]
# Predicting: 1it [00:02,  2.40s/it]
# Predicting: 2it [00:05,  2.99s/it]
# Predicting: 3it [00:17,  7.16s/it]
# Predicting: 4it [00:19,  4.81s/it]
# Predicting: 5it [00:20,  3.62s/it]
# Predicting: 6it [00:27,  4.78s/it]
# Predicting: 7it [00:39,  7.14s/it]
# Predicting: 8it [00:51,  8.49s/it]
# Predicting: 9it [01:01,  8.97s/it]
# Predicting: 10it [01:02,  6.55s/it]
# Predicting: 11it [01:02,  4.72s/it]
# Predicting: 12it [01:13,  6.53s/it]
# Predicting: 13it [01:25,  8.19s/it]
# Predicting: 14it [01:27,  6.28s/it]
# Predicting: 15it [01:38,  7.88s/it]
# Predicting: 16it [01:43,  6.98s/it]
# Predicting: 17it [01:55,  8.48s/it]
# Predicting: 18it [01:59,  6.91s/it]
# Predicting: 19it [02:05,  6.84s/it]
# Predicting: 20it [02:12,  6.88s/it]
# Predicting: 21it [02:20,  7.23s/it]
# Predicting: 22it [02:24,  6.17s/it]
# Predicting: 23it [02:31,  6.51s/it]
# Predicting: 24it [02:32,  4.72s/it]
# Predicting: 25it [02:44,  6.85s/it]
# Predicting: 26it [02:51,  7.09s/it]
# Predicting: 27it [02:56,  6.54s/it]
# Predicting: 28it [02:57,  4.79s/it]
# Predicting: 29it [03:09,  6.89s/it]
# Predicting: 30it [03:10,  5.19s/it]
# Predicting: 31it [03:12,  4.05s/it]
# Predicting: 32it [03:23,  6.36s/it]
# Predicting: 33it [03:25,  5.01s/it]
# Predicting: 34it [03:27,  4.07s/it]
# Predicting: 35it [03:27,  2.96s/it]
# Predicting: 36it [03:28,  2.21s/it]
# Predicting: 37it [03:34,  3.52s/it]
# Predicting: 38it [03:42,  4.73s/it]
# Predicting: 39it [03:54,  6.89s/it]
# Predicting: 40it [03:54,  4.96s/it]
# Predicting: 41it [03:59,  4.87s/it]
# Predicting: 42it [04:00,  3.71s/it]
# Predicting: 43it [04:06,  4.39s/it]
# Predicting: 44it [04:11,  4.66s/it]
# Predicting: 45it [04:23,  6.88s/it]
# Predicting: 46it [04:29,  6.47s/it]
# Predicting: 47it [04:33,  5.83s/it]
# Predicting: 48it [04:36,  4.91s/it]
# Predicting: 49it [04:37,  3.88s/it]
# Predicting: 50it [04:50,  5.80s/it]
# Generating:  15%|█▌        | 3/20 [14:25<1:20:50, 285.32s/it]
# Predicting: 0it [00:00, ?it/s]
# Predicting: 1it [00:05,  5.61s/it]
# Predicting: 2it [00:06,  2.68s/it]
# Predicting: 3it [00:06,  1.63s/it]
# Predicting: 4it [00:11,  2.74s/it]
# Predicting: 5it [00:23,  6.09s/it]
# Predicting: 6it [00:23,  4.32s/it]
# Predicting: 7it [00:24,  3.24s/it]
# Predicting: 8it [00:34,  5.20s/it]
# Predicting: 9it [00:34,  3.75s/it]
# Predicting: 10it [00:37,  3.36s/it]
# Predicting: 11it [00:42,  3.78s/it]
# Predicting: 12it [00:48,  4.47s/it]
# Predicting: 13it [00:49,  3.38s/it]
# Predicting: 14it [00:49,  2.63s/it]
# Predicting: 15it [01:01,  5.36s/it]
# Predicting: 16it [01:06,  5.27s/it]
# Predicting: 17it [01:07,  4.06s/it]
# Predicting: 18it [01:11,  3.93s/it]
# Predicting: 19it [01:14,  3.75s/it]
# Predicting: 20it [01:15,  2.82s/it]
# Predicting: 21it [01:17,  2.44s/it]
# Predicting: 22it [01:18,  2.15s/it]
# Predicting: 23it [01:25,  3.43s/it]
# Predicting: 24it [01:27,  3.26s/it]
# Predicting: 25it [01:39,  5.88s/it]
# Predicting: 26it [01:50,  7.37s/it]
# Predicting: 27it [02:02,  8.75s/it]
# Predicting: 28it [02:09,  8.16s/it]
# Predicting: 29it [02:13,  7.04s/it]
# Predicting: 30it [02:14,  5.14s/it]
# Predicting: 31it [02:25,  6.73s/it]
# Predicting: 32it [02:26,  5.17s/it]
# Predicting: 33it [02:27,  3.83s/it]
# Predicting: 34it [02:28,  2.91s/it]
# Predicting: 35it [02:29,  2.48s/it]
# Predicting: 36it [02:32,  2.66s/it]
# Predicting: 37it [02:33,  2.13s/it]
# Predicting: 38it [02:34,  1.67s/it]
# Predicting: 39it [02:46,  4.77s/it]
# Predicting: 40it [02:50,  4.79s/it]
# Predicting: 41it [02:56,  5.03s/it]
# Predicting: 42it [02:57,  3.72s/it]
# Predicting: 43it [03:00,  3.65s/it]
# Predicting: 44it [03:12,  6.15s/it]
# Predicting: 45it [03:16,  5.43s/it]
# Predicting: 46it [03:17,  4.04s/it]
# Predicting: 47it [03:26,  5.64s/it]
# Predicting: 48it [03:27,  4.16s/it]
# Predicting: 49it [03:31,  4.25s/it]
# Predicting: 50it [03:35,  4.31s/it]
# Generating:  20%|██        | 4/20 [18:00<1:08:43, 257.75s/it]
# Predicting: 0it [00:00, ?it/s]
# Predicting: 1it [00:03,  3.55s/it]
# Predicting: 2it [00:04,  2.01s/it]
# Predicting: 3it [00:16,  6.56s/it]
# Predicting: 4it [00:17,  4.50s/it]
# Predicting: 5it [00:19,  3.43s/it]
# Predicting: 6it [00:26,  4.67s/it]
# Predicting: 7it [00:26,  3.30s/it]
# Predicting: 8it [00:27,  2.30s/it]
# Predicting: 9it [00:29,  2.46s/it]
# Predicting: 10it [00:41,  5.40s/it]
# Predicting: 11it [00:42,  4.00s/it]
# Predicting: 12it [00:44,  3.38s/it]
# Predicting: 13it [00:45,  2.54s/it]
# Predicting: 14it [00:46,  2.09s/it]
# Predicting: 15it [00:58,  5.05s/it]
# Predicting: 16it [00:59,  3.83s/it]
# Predicting: 17it [01:00,  3.10s/it]
# Predicting: 18it [01:07,  4.24s/it]
# Predicting: 19it [01:07,  3.11s/it]
# Predicting: 20it [01:08,  2.38s/it]
# Predicting: 21it [01:20,  5.26s/it]
# Predicting: 22it [01:32,  7.26s/it]
# Predicting: 23it [01:33,  5.39s/it]
# Predicting: 24it [01:33,  3.86s/it]
# Predicting: 25it [01:34,  2.76s/it]
# Predicting: 26it [01:36,  2.62s/it]
# Predicting: 27it [01:39,  2.79s/it]
# Predicting: 28it [01:42,  2.93s/it]
# Predicting: 29it [01:47,  3.47s/it]
# Predicting: 30it [01:59,  6.05s/it]
# Predicting: 31it [02:00,  4.49s/it]
# Predicting: 32it [02:07,  5.29s/it]
# Predicting: 33it [02:13,  5.57s/it]
# Predicting: 34it [02:18,  5.16s/it]
# Predicting: 35it [02:29,  7.18s/it]
# Predicting: 36it [02:34,  6.50s/it]
# Predicting: 37it [02:35,  4.65s/it]
# Predicting: 38it [02:42,  5.37s/it]
# Predicting: 39it [02:43,  4.27s/it]
# Predicting: 40it [02:44,  3.07s/it]
# Predicting: 41it [02:55,  5.58s/it]
# Predicting: 42it [02:56,  4.02s/it]
# Predicting: 43it [03:07,  6.39s/it]
# Predicting: 44it [03:08,  4.61s/it]
# Predicting: 45it [03:20,  6.83s/it]
# Predicting: 46it [03:26,  6.72s/it]
# Predicting: 47it [03:30,  5.71s/it]
# Predicting: 48it [03:42,  7.56s/it]
# Predicting: 49it [03:44,  6.11s/it]
# Predicting: 50it [03:56,  4.73s/it]
# Generating:  25%|██▌       | 5/20 [21:57<1:02:32, 250.17s/it]
# Predicting: 0it [00:00, ?it/s]
# Predicting: 1it [00:00,  1.37it/s]
# Predicting: 2it [00:11,  6.36s/it]
# Predicting: 3it [00:16,  5.86s/it]
# Predicting: 4it [00:17,  3.84s/it]
# Predicting: 5it [00:28,  6.76s/it]
# Predicting: 6it [00:34,  6.20s/it]
# Predicting: 7it [00:34,  4.44s/it]
# Predicting: 8it [00:36,  3.47s/it]
# Predicting: 9it [00:37,  2.73s/it]
# Predicting: 10it [00:49,  5.59s/it]
# Predicting: 11it [00:53,  5.23s/it]
# Predicting: 12it [01:05,  7.27s/it]
# Predicting: 13it [01:06,  5.33s/it]
# Predicting: 14it [01:13,  5.91s/it]
# Predicting: 15it [01:25,  7.75s/it]
# Predicting: 16it [01:26,  5.69s/it]
# Predicting: 17it [01:35,  6.58s/it]
# Predicting: 18it [01:36,  4.89s/it]
# Predicting: 19it [01:41,  4.97s/it]
# Predicting: 20it [01:41,  3.56s/it]
# Predicting: 21it [01:53,  6.09s/it]
# Predicting: 22it [01:57,  5.39s/it]
# Predicting: 23it [01:57,  3.86s/it]
# Predicting: 24it [02:04,  4.56s/it]
# Predicting: 25it [02:05,  3.52s/it]
# Predicting: 26it [02:08,  3.40s/it]
# Predicting: 27it [02:09,  2.78s/it]
# Predicting: 28it [02:18,  4.57s/it]
# Predicting: 29it [02:29,  6.61s/it]
# Predicting: 30it [02:34,  5.93s/it]
# Predicting: 31it [02:41,  6.36s/it]
# Predicting: 32it [02:47,  6.32s/it]
# Predicting: 33it [02:59,  8.01s/it]
# Predicting: 34it [03:00,  5.81s/it]
# Predicting: 35it [03:00,  4.22s/it]
# Predicting: 36it [03:01,  3.24s/it]
# Predicting: 37it [03:07,  4.13s/it]
# Predicting: 38it [03:10,  3.71s/it]
# Predicting: 39it [03:11,  2.75s/it]
# Predicting: 40it [03:11,  2.14s/it]
# Predicting: 41it [03:12,  1.72s/it]
# Predicting: 42it [03:17,  2.69s/it]
# Predicting: 43it [03:24,  4.06s/it]
# Predicting: 44it [03:36,  6.44s/it]
# Predicting: 45it [03:41,  5.84s/it]
# Predicting: 46it [03:41,  4.26s/it]
# Predicting: 47it [03:43,  3.63s/it]
# Predicting: 48it [03:56,  6.16s/it]
# Predicting: 49it [04:07,  7.65s/it]
# Predicting: 50it [04:08,  4.96s/it]
# Generating:  30%|███       | 6/20 [26:05<58:12, 249.48s/it]
# Predicting: 0it [00:00, ?it/s]
# Predicting: 1it [00:01,  1.54s/it]
# Predicting: 2it [00:12,  6.98s/it]
# Predicting: 3it [00:24,  9.31s/it]
# Predicting: 4it [00:36, 10.34s/it]
# Predicting: 5it [00:41,  8.41s/it]
# Predicting: 6it [00:42,  5.83s/it]
# Predicting: 7it [00:53,  7.71s/it]
# Predicting: 8it [01:05,  9.07s/it]
# Predicting: 9it [01:17,  9.96s/it]
# Predicting: 10it [01:28, 10.33s/it]
# Predicting: 11it [01:29,  7.39s/it]
# Predicting: 12it [01:31,  5.66s/it]
# Predicting: 13it [01:32,  4.25s/it]
# Predicting: 14it [01:44,  6.58s/it]
# Predicting: 15it [01:47,  5.68s/it]
# Predicting: 16it [01:59,  7.51s/it]
# Predicting: 17it [02:01,  5.88s/it]
# Predicting: 18it [02:02,  4.43s/it]
# Predicting: 19it [02:14,  6.70s/it]
# Predicting: 20it [02:14,  4.75s/it]
# Predicting: 21it [02:24,  6.10s/it]
# Predicting: 22it [02:28,  5.48s/it]
# Predicting: 23it [02:34,  5.85s/it]
# Predicting: 24it [02:42,  6.26s/it]
# Predicting: 25it [02:47,  6.11s/it]
# Predicting: 26it [02:49,  4.71s/it]
# Predicting: 27it [02:49,  3.49s/it]
# Predicting: 28it [02:50,  2.56s/it]
# Predicting: 29it [02:53,  2.66s/it]
# Predicting: 30it [02:54,  2.15s/it]
# Predicting: 31it [02:57,  2.61s/it]
# Predicting: 32it [03:04,  3.75s/it]
# Predicting: 33it [03:09,  4.30s/it]
# Predicting: 34it [03:10,  3.21s/it]
# Predicting: 35it [03:11,  2.54s/it]
# Predicting: 36it [03:18,  3.83s/it]
# Predicting: 37it [03:26,  5.26s/it]
# Predicting: 38it [03:32,  5.28s/it]
# Predicting: 39it [03:44,  7.21s/it]
# Predicting: 40it [03:48,  6.50s/it]
# Predicting: 41it [03:49,  4.76s/it]
# Predicting: 42it [03:50,  3.76s/it]
# Predicting: 43it [03:53,  3.30s/it]
# Predicting: 44it [03:55,  2.91s/it]
# Predicting: 45it [03:55,  2.15s/it]
# Predicting: 46it [04:01,  3.21s/it]
# Predicting: 47it [04:02,  2.51s/it]
# Predicting: 48it [04:06,  3.03s/it]
# Predicting: 49it [04:18,  5.69s/it]
# Predicting: 50it [04:22,  5.24s/it]
# Generating:  35%|███▌      | 7/20 [30:27<54:57, 253.64s/it]
# Predicting: 0it [00:00, ?it/s]
# Predicting: 1it [00:02,  2.02s/it]
# Predicting: 2it [00:02,  1.25s/it]
# Predicting: 3it [00:06,  2.60s/it]
# Predicting: 4it [00:07,  1.85s/it]
# Predicting: 5it [00:08,  1.34s/it]
# Predicting: 6it [00:17,  4.03s/it]
# Predicting: 7it [00:25,  5.45s/it]
# Predicting: 8it [00:36,  7.16s/it]
# Predicting: 9it [00:41,  6.37s/it]
# Predicting: 10it [00:41,  4.49s/it]
# Predicting: 11it [00:47,  4.88s/it]
# Predicting: 12it [00:50,  4.37s/it]
# Predicting: 13it [00:54,  4.40s/it]
# Predicting: 14it [01:06,  6.70s/it]
# Predicting: 15it [01:15,  7.14s/it]
# Predicting: 16it [01:15,  5.20s/it]
# Predicting: 17it [01:22,  5.69s/it]
# Predicting: 18it [01:22,  4.03s/it]
# Predicting: 19it [01:34,  6.36s/it]
# Predicting: 20it [01:46,  8.02s/it]
# Predicting: 21it [01:58,  9.19s/it]
# Predicting: 22it [02:04,  8.24s/it]
# Predicting: 23it [02:11,  8.00s/it]
# Predicting: 24it [02:23,  9.20s/it]
# Predicting: 25it [02:29,  8.13s/it]
# Predicting: 26it [02:36,  7.73s/it]
# Predicting: 27it [02:36,  5.53s/it]
# Predicting: 28it [02:47,  7.19s/it]
# Predicting: 29it [02:48,  5.40s/it]
# Predicting: 30it [03:00,  7.25s/it]
# Predicting: 31it [03:12,  8.56s/it]
# Predicting: 32it [03:17,  7.55s/it]
# Predicting: 33it [03:19,  5.89s/it]
# Predicting: 34it [03:19,  4.27s/it]
# Predicting: 35it [03:20,  3.20s/it]
# Predicting: 36it [03:30,  5.29s/it]
# Predicting: 37it [03:42,  7.26s/it]
# Predicting: 38it [03:54,  8.71s/it]
# Predicting: 39it [03:55,  6.51s/it]
# Predicting: 40it [03:56,  4.75s/it]
# Predicting: 41it [03:59,  4.29s/it]
# Predicting: 42it [04:03,  4.08s/it]
# Predicting: 43it [04:12,  5.66s/it]
# Predicting: 44it [04:24,  7.53s/it]
# Predicting: 45it [04:36,  8.83s/it]
# Predicting: 46it [04:38,  6.76s/it]
# Predicting: 47it [04:38,  4.86s/it]
# Predicting: 48it [04:50,  6.99s/it]
# Predicting: 49it [04:51,  5.08s/it]
# Predicting: 50it [04:52,  5.85s/it]
# Generating:  40%|████      | 8/20 [35:20<53:12, 266.05s/it]
# Predicting: 0it [00:00, ?it/s]
# Predicting: 1it [00:06,  6.58s/it]
# Predicting: 2it [00:06,  2.94s/it]
# Predicting: 3it [00:13,  4.50s/it]
# Predicting: 4it [00:18,  4.57s/it]
# Predicting: 5it [00:18,  3.19s/it]
# Predicting: 6it [00:29,  5.60s/it]
# Predicting: 7it [00:37,  6.60s/it]
# Predicting: 8it [00:49,  8.30s/it]
# Predicting: 9it [00:50,  5.88s/it]
# Predicting: 10it [00:55,  5.56s/it]
# Predicting: 11it [01:06,  7.47s/it]
# Predicting: 12it [01:18,  8.81s/it]
# Predicting: 13it [01:30,  9.71s/it]
# Predicting: 14it [01:42, 10.38s/it]
# Predicting: 15it [01:53, 10.48s/it]
# Predicting: 16it [02:05, 10.92s/it]
# Predicting: 17it [02:12,  9.99s/it]
# Predicting: 18it [02:13,  7.10s/it]
# Predicting: 19it [02:17,  6.36s/it]
# Predicting: 20it [02:18,  4.54s/it]
# Predicting: 21it [02:18,  3.25s/it]
# Predicting: 22it [02:20,  2.78s/it]
# Predicting: 23it [02:21,  2.31s/it]
# Predicting: 24it [02:21,  1.75s/it]
# Predicting: 25it [02:22,  1.33s/it]
# Predicting: 26it [02:32,  4.01s/it]
# Predicting: 27it [02:37,  4.35s/it]
# Predicting: 28it [02:49,  6.58s/it]
# Predicting: 29it [02:51,  5.19s/it]
# Predicting: 30it [03:03,  7.17s/it]
# Predicting: 32it [03:04,  4.09s/it]
# Predicting: 33it [03:05,  3.47s/it]
# Predicting: 34it [03:07,  2.96s/it]
# Predicting: 35it [03:08,  2.40s/it]
# Predicting: 36it [03:19,  5.05s/it]
# Predicting: 37it [03:20,  3.90s/it]
# Predicting: 38it [03:32,  6.22s/it]
# Predicting: 39it [03:33,  4.58s/it]
# Predicting: 40it [03:37,  4.38s/it]
# Predicting: 41it [03:47,  5.97s/it]
# Predicting: 42it [03:47,  4.43s/it]
# Predicting: 43it [03:49,  3.44s/it]
# Predicting: 44it [03:56,  4.61s/it]
# Predicting: 45it [03:59,  4.08s/it]
# Predicting: 46it [04:07,  5.38s/it]
# Predicting: 47it [04:19,  7.30s/it]
# Predicting: 48it [04:31,  8.67s/it]
# Predicting: 49it [04:31,  6.21s/it]
# Predicting: 50it [04:32,  5.44s/it]
# Generating:  45%|████▌     | 9/20 [39:52<49:07, 267.97s/it]
# Predicting: 0it [00:00, ?it/s]
# Predicting: 1it [00:00,  1.17it/s]
# Predicting: 2it [00:01,  1.13it/s]
# Predicting: 3it [00:01,  1.72it/s]
# Predicting: 4it [00:07,  2.34s/it]
# Predicting: 5it [00:14,  4.03s/it]
# Predicting: 6it [00:19,  4.66s/it]
# Predicting: 7it [00:30,  6.52s/it]
# Predicting: 8it [00:33,  5.53s/it]
# Predicting: 9it [00:34,  3.93s/it]
# Predicting: 10it [00:46,  6.42s/it]
# Predicting: 11it [00:46,  4.69s/it]
# Predicting: 12it [00:57,  6.39s/it]
# Predicting: 13it [00:57,  4.58s/it]
# Predicting: 14it [01:03,  5.05s/it]
# Predicting: 15it [01:06,  4.33s/it]
# Predicting: 16it [01:17,  6.28s/it]
# Predicting: 17it [01:17,  4.44s/it]
# Predicting: 18it [01:24,  5.25s/it]
# Predicting: 19it [01:25,  3.95s/it]
# Predicting: 20it [01:30,  4.34s/it]
# Predicting: 21it [01:31,  3.32s/it]
# Predicting: 22it [01:32,  2.50s/it]
# Predicting: 23it [01:42,  4.84s/it]
# Predicting: 24it [01:54,  6.97s/it]
# Predicting: 25it [01:57,  5.83s/it]
# Predicting: 26it [02:09,  7.69s/it]
# Predicting: 27it [02:15,  7.20s/it]
# Predicting: 28it [02:16,  5.18s/it]
# Predicting: 29it [02:18,  4.25s/it]
# Predicting: 30it [02:23,  4.71s/it]
# Predicting: 31it [02:25,  3.61s/it]
# Predicting: 32it [02:33,  5.16s/it]
# Predicting: 33it [02:45,  7.20s/it]
# Predicting: 34it [02:51,  6.63s/it]
# Predicting: 35it [02:56,  6.29s/it]
# Predicting: 36it [03:08,  7.98s/it]
# Predicting: 37it [03:14,  7.27s/it]
# Predicting: 38it [03:18,  6.48s/it]
# Predicting: 39it [03:19,  4.65s/it]
# Predicting: 40it [03:30,  6.68s/it]
# Predicting: 41it [03:31,  4.96s/it]
# Predicting: 42it [03:32,  3.66s/it]
# Predicting: 43it [03:43,  6.02s/it]
# Predicting: 44it [03:44,  4.49s/it]
# Predicting: 45it [03:55,  6.55s/it]
# Predicting: 46it [04:04,  7.28s/it]
# Predicting: 47it [04:06,  5.56s/it]
# Predicting: 48it [04:07,  4.32s/it]
# Predicting: 49it [04:14,  5.12s/it]
# Predicting: 50it [04:26,  5.33s/it]
# Generating:  50%|█████     | 10/20 [44:19<44:35, 267.59s/it]
# Predicting: 0it [00:00, ?it/s]
# Predicting: 1it [00:00,  2.62it/s]
# Predicting: 2it [00:02,  1.17s/it]
# Predicting: 3it [00:03,  1.10s/it]
# Predicting: 4it [00:15,  5.36s/it]
# Predicting: 5it [00:17,  4.36s/it]
# Predicting: 6it [00:29,  6.94s/it]
# Predicting: 7it [00:30,  4.85s/it]
# Predicting: 8it [00:41,  7.08s/it]
# Predicting: 9it [00:42,  4.93s/it]
# Predicting: 10it [00:43,  3.68s/it]
# Predicting: 11it [00:44,  3.09s/it]
# Predicting: 12it [00:47,  3.07s/it]
# Predicting: 13it [00:56,  4.72s/it]
# Predicting: 14it [00:58,  3.96s/it]
# Predicting: 15it [01:00,  3.45s/it]
# Predicting: 16it [01:12,  5.92s/it]
# Predicting: 17it [01:24,  7.68s/it]
# Predicting: 18it [01:36,  8.94s/it]
# Predicting: 19it [01:39,  7.33s/it]
# Predicting: 20it [01:41,  5.72s/it]
# Predicting: 21it [01:50,  6.51s/it]
# Predicting: 22it [02:02,  8.16s/it]
# Predicting: 23it [02:12,  8.77s/it]
# Predicting: 24it [02:18,  7.91s/it]
# Predicting: 25it [02:21,  6.41s/it]
# Predicting: 26it [02:21,  4.57s/it]
# Predicting: 27it [02:23,  3.95s/it]
# Predicting: 28it [02:34,  5.97s/it]
# Predicting: 29it [02:35,  4.54s/it]
# Predicting: 30it [02:36,  3.54s/it]
# Predicting: 31it [02:38,  2.99s/it]
# Predicting: 32it [02:50,  5.68s/it]
# Predicting: 33it [02:55,  5.45s/it]
# Predicting: 34it [03:07,  7.36s/it]
# Predicting: 35it [03:19,  8.75s/it]
# Predicting: 36it [03:30,  9.52s/it]
# Predicting: 37it [03:32,  7.35s/it]
# Predicting: 38it [03:34,  5.76s/it]
# Predicting: 39it [03:39,  5.30s/it]
# Predicting: 40it [03:41,  4.39s/it]
# Predicting: 41it [03:41,  3.19s/it]
# Predicting: 42it [03:50,  4.88s/it]
# Predicting: 43it [04:01,  6.75s/it]
# Predicting: 44it [04:02,  4.92s/it]
# Predicting: 45it [04:05,  4.39s/it]
# Predicting: 46it [04:06,  3.40s/it]
# Predicting: 47it [04:07,  2.51s/it]
# Predicting: 48it [04:13,  3.76s/it]
# Predicting: 49it [04:16,  3.38s/it]
# Predicting: 50it [04:17,  5.15s/it]
# Generating:  55%|█████▌    | 11/20 [48:37<39:41, 264.57s/it]
# Predicting: 0it [00:00, ?it/s]
# Predicting: 1it [00:01,  1.83s/it]
# Predicting: 2it [00:04,  2.61s/it]
# Predicting: 3it [00:08,  2.99s/it]
# Predicting: 4it [00:15,  4.71s/it]
# Predicting: 5it [00:19,  4.39s/it]
# Predicting: 6it [00:30,  6.57s/it]
# Predicting: 7it [00:31,  4.77s/it]
# Predicting: 8it [00:35,  4.48s/it]
# Predicting: 9it [00:35,  3.21s/it]
# Predicting: 10it [00:44,  4.88s/it]
# Predicting: 11it [00:49,  5.11s/it]
# Predicting: 12it [01:01,  7.09s/it]
# Predicting: 13it [01:02,  5.10s/it]
# Predicting: 14it [01:10,  6.09s/it]
# Predicting: 15it [01:10,  4.38s/it]
# Predicting: 16it [01:20,  5.93s/it]
# Predicting: 17it [01:21,  4.32s/it]
# Predicting: 18it [01:24,  3.92s/it]
# Predicting: 19it [01:31,  4.85s/it]
# Predicting: 20it [01:31,  3.50s/it]
# Predicting: 21it [01:31,  2.59s/it]
# Predicting: 22it [01:33,  2.28s/it]
# Predicting: 23it [01:34,  1.79s/it]
# Predicting: 24it [01:41,  3.61s/it]
# Predicting: 25it [01:44,  3.29s/it]
# Predicting: 26it [01:45,  2.61s/it]
# Predicting: 27it [01:57,  5.40s/it]
# Predicting: 28it [02:09,  7.32s/it]
# Predicting: 29it [02:12,  6.21s/it]
# Predicting: 30it [02:13,  4.63s/it]
# Predicting: 31it [02:17,  4.32s/it]
# Predicting: 32it [02:18,  3.35s/it]
# Predicting: 33it [02:30,  5.82s/it]
# Predicting: 34it [02:41,  7.57s/it]
# Predicting: 35it [02:42,  5.54s/it]
# Predicting: 36it [02:44,  4.47s/it]
# Predicting: 37it [02:45,  3.38s/it]
# Predicting: 38it [02:56,  5.82s/it]
# Predicting: 39it [02:57,  4.23s/it]
# Predicting: 40it [03:01,  4.11s/it]
# Predicting: 41it [03:02,  3.41s/it]
# Predicting: 42it [03:03,  2.49s/it]
# Predicting: 43it [03:14,  5.12s/it]
# Predicting: 44it [03:14,  3.68s/it]
# Predicting: 45it [03:19,  3.95s/it]
# Predicting: 46it [03:20,  2.96s/it]
# Predicting: 47it [03:21,  2.35s/it]
# Predicting: 48it [03:29,  4.14s/it]
# Predicting: 49it [03:37,  5.21s/it]
# Predicting: 50it [03:38,  4.37s/it]
# Generating:  60%|██████    | 12/20 [52:15<33:24, 250.52s/it]
# Predicting: 0it [00:00, ?it/s]
# Predicting: 1it [00:01,  1.32s/it]
# Predicting: 2it [00:01,  1.54it/s]
# Predicting: 3it [00:13,  5.77s/it]
# Predicting: 4it [00:17,  4.98s/it]
# Predicting: 5it [00:20,  4.27s/it]
# Predicting: 6it [00:21,  3.34s/it]
# Predicting: 7it [00:22,  2.48s/it]
# Predicting: 8it [00:30,  4.27s/it]
# Predicting: 9it [00:31,  3.29s/it]
# Predicting: 10it [00:31,  2.38s/it]
# Predicting: 11it [00:32,  1.77s/it]
# Predicting: 12it [00:33,  1.59s/it]
# Predicting: 13it [00:39,  2.82s/it]
# Predicting: 14it [00:51,  5.61s/it]
# Predicting: 15it [00:51,  4.03s/it]
# Predicting: 16it [01:02,  6.18s/it]
# Predicting: 17it [01:13,  7.58s/it]
# Predicting: 18it [01:14,  5.46s/it]
# Predicting: 19it [01:19,  5.29s/it]
# Predicting: 20it [01:21,  4.43s/it]
# Predicting: 21it [01:33,  6.64s/it]
# Predicting: 22it [01:35,  5.35s/it]
# Predicting: 23it [01:36,  4.04s/it]
# Predicting: 24it [01:42,  4.71s/it]
# Predicting: 25it [01:54,  6.72s/it]
# Predicting: 26it [01:54,  4.88s/it]
# Predicting: 27it [01:56,  3.76s/it]
# Predicting: 28it [01:59,  3.68s/it]
# Predicting: 29it [02:00,  2.82s/it]
# Predicting: 30it [02:05,  3.58s/it]
# Predicting: 31it [02:08,  3.49s/it]
# Predicting: 32it [02:10,  2.94s/it]
# Predicting: 33it [02:22,  5.62s/it]
# Predicting: 34it [02:26,  5.14s/it]
# Predicting: 35it [02:27,  3.84s/it]
# Predicting: 36it [02:35,  5.09s/it]
# Predicting: 37it [02:39,  4.92s/it]
# Predicting: 38it [02:51,  7.01s/it]
# Predicting: 39it [02:55,  6.19s/it]
# Predicting: 40it [03:03,  6.71s/it]
# Predicting: 41it [03:04,  4.95s/it]
# Predicting: 42it [03:06,  3.85s/it]
# Predicting: 43it [03:12,  4.77s/it]
# Predicting: 44it [03:14,  3.91s/it]
# Predicting: 45it [03:18,  3.77s/it]
# Predicting: 46it [03:30,  6.20s/it]
# Predicting: 47it [03:42,  7.93s/it]
# Predicting: 48it [03:42,  5.60s/it]
# Predicting: 49it [03:42,  4.10s/it]
# Predicting: 50it [03:48,  4.56s/it]
# Generating:  65%|██████▌   | 13/20 [56:03<28:26, 243.72s/it]
# Predicting: 0it [00:00, ?it/s]
# Predicting: 1it [00:11, 11.90s/it]
# Predicting: 2it [00:12,  5.48s/it]
# Predicting: 3it [00:24,  8.36s/it]
# Predicting: 4it [00:28,  6.45s/it]
# Predicting: 5it [00:29,  4.59s/it]
# Predicting: 6it [00:34,  4.72s/it]
# Predicting: 7it [00:37,  4.22s/it]
# Predicting: 8it [00:38,  3.04s/it]
# Predicting: 9it [00:44,  4.17s/it]
# Predicting: 10it [00:51,  4.80s/it]
# Predicting: 11it [00:57,  5.19s/it]
# Predicting: 12it [00:57,  3.75s/it]
# Predicting: 13it [01:07,  5.53s/it]
# Predicting: 14it [01:12,  5.51s/it]
# Predicting: 15it [01:13,  4.16s/it]
# Predicting: 16it [01:25,  6.45s/it]
# Predicting: 17it [01:26,  4.69s/it]
# Predicting: 18it [01:36,  6.38s/it]
# Predicting: 19it [01:40,  5.83s/it]
# Predicting: 20it [01:52,  7.64s/it]
# Predicting: 21it [02:00,  7.58s/it]
# Predicting: 22it [02:02,  6.03s/it]
# Predicting: 23it [02:03,  4.62s/it]
# Predicting: 24it [02:04,  3.50s/it]
# Predicting: 25it [02:08,  3.67s/it]
# Predicting: 26it [02:14,  4.12s/it]
# Predicting: 27it [02:17,  3.81s/it]
# Predicting: 28it [02:20,  3.71s/it]
# Predicting: 29it [02:24,  3.72s/it]
# Predicting: 30it [02:27,  3.61s/it]
# Predicting: 31it [02:29,  3.08s/it]
# Predicting: 32it [02:41,  5.72s/it]
# Predicting: 33it [02:44,  4.77s/it]
# Predicting: 34it [02:46,  4.13s/it]
# Predicting: 35it [02:49,  3.84s/it]
# Predicting: 36it [02:51,  3.07s/it]
# Predicting: 37it [03:02,  5.60s/it]
# Predicting: 38it [03:04,  4.46s/it]
# Predicting: 39it [03:05,  3.39s/it]
# Predicting: 40it [03:06,  2.65s/it]
# Predicting: 41it [03:14,  4.21s/it]
# Predicting: 42it [03:24,  6.16s/it]
# Predicting: 43it [03:30,  6.10s/it]
# Predicting: 44it [03:31,  4.53s/it]
# Predicting: 45it [03:36,  4.57s/it]
# Predicting: 46it [03:48,  6.75s/it]
# Predicting: 47it [03:59,  8.26s/it]
# Predicting: 48it [04:06,  7.87s/it]
# Predicting: 49it [04:18,  9.04s/it]
# Predicting: 50it [04:19,  5.20s/it]
# Generating:  70%|███████   | 14/20 [1:00:23<24:51, 248.59s/it]
# Predicting: 0it [00:00, ?it/s]
# Predicting: 1it [00:00,  3.52it/s]
# Predicting: 2it [00:07,  4.32s/it]
# Predicting: 3it [00:13,  5.28s/it]
# Predicting: 4it [00:16,  4.17s/it]
# Predicting: 5it [00:18,  3.54s/it]
# Predicting: 6it [00:19,  2.53s/it]
# Predicting: 7it [00:31,  5.55s/it]
# Predicting: 8it [00:35,  5.13s/it]
# Predicting: 9it [00:35,  3.66s/it]
# Predicting: 10it [00:37,  3.03s/it]
# Predicting: 11it [00:38,  2.33s/it]
# Predicting: 12it [00:47,  4.35s/it]
# Predicting: 13it [00:58,  6.62s/it]
# Predicting: 14it [01:06,  6.94s/it]
# Predicting: 15it [01:17,  8.28s/it]
# Predicting: 16it [01:29,  9.33s/it]
# Predicting: 17it [01:31,  6.97s/it]
# Predicting: 18it [01:32,  5.13s/it]
# Predicting: 19it [01:32,  3.82s/it]
# Predicting: 20it [01:35,  3.57s/it]
# Predicting: 21it [01:47,  6.05s/it]
# Predicting: 22it [01:48,  4.41s/it]
# Predicting: 23it [01:48,  3.20s/it]
# Predicting: 24it [02:00,  5.79s/it]
# Predicting: 25it [02:01,  4.40s/it]
# Predicting: 26it [02:13,  6.66s/it]
# Predicting: 27it [02:13,  4.76s/it]
# Predicting: 28it [02:15,  3.70s/it]
# Predicting: 29it [02:27,  6.18s/it]
# Predicting: 30it [02:38,  7.89s/it]
# Predicting: 31it [02:42,  6.63s/it]
# Predicting: 32it [02:43,  4.98s/it]
# Predicting: 33it [02:55,  7.05s/it]
# Predicting: 34it [02:56,  5.09s/it]
# Predicting: 35it [02:56,  3.66s/it]
# Predicting: 36it [02:57,  2.81s/it]
# Predicting: 37it [02:58,  2.39s/it]
# Predicting: 38it [02:59,  1.98s/it]
# Predicting: 39it [03:05,  3.08s/it]
# Predicting: 40it [03:06,  2.52s/it]
# Predicting: 41it [03:16,  4.63s/it]
# Predicting: 42it [03:16,  3.38s/it]
# Predicting: 43it [03:23,  4.51s/it]
# Predicting: 44it [03:24,  3.31s/it]
# Predicting: 45it [03:25,  2.58s/it]
# Predicting: 46it [03:36,  5.33s/it]
# Predicting: 47it [03:37,  3.83s/it]
# Predicting: 48it [03:38,  3.05s/it]
# Predicting: 49it [03:43,  3.53s/it]
# Predicting: 50it [03:54,  4.68s/it]
# Generating:  75%|███████▌  | 15/20 [1:04:17<20:21, 244.27s/it]
# Predicting: 0it [00:00, ?it/s]
# Predicting: 1it [00:03,  3.11s/it]
# Predicting: 2it [00:13,  7.23s/it]
# Predicting: 3it [00:15,  4.75s/it]
# Predicting: 4it [00:15,  3.15s/it]
# Predicting: 5it [00:26,  5.73s/it]
# Predicting: 6it [00:26,  4.06s/it]
# Predicting: 7it [00:30,  4.08s/it]
# Predicting: 8it [00:42,  6.51s/it]
# Predicting: 9it [00:54,  8.18s/it]
# Predicting: 10it [01:06,  9.28s/it]
# Predicting: 11it [01:14,  8.97s/it]
# Predicting: 12it [01:18,  7.47s/it]
# Predicting: 13it [01:19,  5.40s/it]
# Predicting: 14it [01:22,  4.90s/it]
# Predicting: 15it [01:23,  3.61s/it]
# Predicting: 16it [01:26,  3.48s/it]
# Predicting: 17it [01:27,  2.61s/it]
# Predicting: 18it [01:34,  3.99s/it]
# Predicting: 19it [01:38,  3.86s/it]
# Predicting: 20it [01:41,  3.81s/it]
# Predicting: 21it [01:43,  3.32s/it]
# Predicting: 22it [01:55,  5.75s/it]
# Predicting: 23it [01:58,  4.98s/it]
# Predicting: 24it [02:10,  6.93s/it]
# Predicting: 25it [02:20,  7.94s/it]
# Predicting: 26it [02:21,  5.83s/it]
# Predicting: 27it [02:27,  6.03s/it]
# Predicting: 28it [02:28,  4.36s/it]
# Predicting: 29it [02:33,  4.62s/it]
# Predicting: 30it [02:34,  3.55s/it]
# Predicting: 31it [02:36,  3.19s/it]
# Predicting: 32it [02:37,  2.52s/it]
# Predicting: 33it [02:38,  1.98s/it]
# Predicting: 34it [02:39,  1.69s/it]
# Predicting: 35it [02:41,  1.70s/it]
# Predicting: 36it [02:44,  2.03s/it]
# Predicting: 37it [02:44,  1.57s/it]
# Predicting: 38it [02:52,  3.40s/it]
# Predicting: 39it [03:03,  5.89s/it]
# Predicting: 40it [03:04,  4.42s/it]
# Predicting: 41it [03:07,  3.92s/it]
# Predicting: 42it [03:09,  3.17s/it]
# Predicting: 43it [03:10,  2.52s/it]
# Predicting: 44it [03:13,  2.71s/it]
# Predicting: 45it [03:18,  3.34s/it]
# Predicting: 46it [03:18,  2.59s/it]
# Predicting: 47it [03:26,  4.13s/it]
# Predicting: 48it [03:33,  4.92s/it]
# Predicting: 49it [03:34,  3.64s/it]
# Predicting: 50it [03:37,  4.35s/it]
# Generating:  80%|████████  | 16/20 [1:07:55<15:44, 236.16s/it]
# Predicting: 0it [00:00, ?it/s]
# Predicting: 1it [00:05,  5.87s/it]
# Predicting: 2it [00:09,  4.73s/it]
# Predicting: 3it [00:10,  2.67s/it]
# Predicting: 4it [00:10,  1.94s/it]
# Predicting: 5it [00:11,  1.49s/it]
# Predicting: 6it [00:14,  1.85s/it]
# Predicting: 7it [00:25,  5.10s/it]
# Predicting: 8it [00:26,  3.71s/it]
# Predicting: 9it [00:29,  3.43s/it]
# Predicting: 10it [00:37,  4.98s/it]
# Predicting: 11it [00:38,  3.69s/it]
# Predicting: 12it [00:39,  2.72s/it]
# Predicting: 13it [00:39,  1.96s/it]
# Predicting: 14it [00:41,  2.05s/it]
# Predicting: 15it [00:43,  1.95s/it]
# Predicting: 16it [00:54,  4.81s/it]
# Predicting: 17it [01:02,  5.56s/it]
# Predicting: 18it [01:04,  4.47s/it]
# Predicting: 19it [01:04,  3.30s/it]
# Predicting: 20it [01:16,  5.88s/it]
# Predicting: 21it [01:20,  5.38s/it]
# Predicting: 22it [01:21,  3.92s/it]
# Predicting: 23it [01:22,  3.25s/it]
# Predicting: 24it [01:23,  2.48s/it]
# Predicting: 25it [01:26,  2.65s/it]
# Predicting: 26it [01:31,  3.41s/it]
# Predicting: 27it [01:43,  5.91s/it]
# Predicting: 28it [01:48,  5.64s/it]
# Predicting: 29it [01:50,  4.40s/it]
# Predicting: 30it [01:55,  4.66s/it]
# Predicting: 31it [02:00,  4.75s/it]
# Predicting: 32it [02:03,  4.34s/it]
# Predicting: 33it [02:03,  3.13s/it]
# Predicting: 34it [02:15,  5.73s/it]
# Predicting: 35it [02:24,  6.49s/it]
# Predicting: 36it [02:29,  6.31s/it]
# Predicting: 37it [02:31,  4.78s/it]
# Predicting: 38it [02:35,  4.64s/it]
# Predicting: 39it [02:38,  4.30s/it]
# Predicting: 40it [02:50,  6.43s/it]
# Predicting: 41it [02:55,  5.96s/it]
# Predicting: 42it [02:56,  4.43s/it]
# Predicting: 43it [03:07,  6.62s/it]
# Predicting: 44it [03:19,  8.19s/it]
# Predicting: 45it [03:24,  7.15s/it]
# Predicting: 46it [03:33,  7.80s/it]
# Predicting: 47it [03:35,  5.91s/it]
# Predicting: 48it [03:35,  4.31s/it]
# Predicting: 49it [03:36,  3.24s/it]
# Predicting: 50it [03:47,  4.55s/it]
# Generating:  85%|████████▌ | 17/20 [1:11:42<11:40, 233.57s/it]
# Predicting: 0it [00:00, ?it/s]
# Predicting: 1it [00:10, 10.09s/it]
# Predicting: 2it [00:15,  7.19s/it]
# Predicting: 3it [00:22,  7.42s/it]
# Predicting: 4it [00:25,  5.31s/it]
# Predicting: 5it [00:29,  4.94s/it]
# Predicting: 6it [00:31,  3.88s/it]
# Predicting: 7it [00:42,  6.48s/it]
# Predicting: 8it [00:54,  8.17s/it]
# Predicting: 9it [01:06,  9.22s/it]
# Predicting: 10it [01:07,  6.60s/it]
# Predicting: 11it [01:18,  8.24s/it]
# Predicting: 12it [01:20,  6.16s/it]
# Predicting: 13it [01:25,  5.94s/it]
# Predicting: 14it [01:30,  5.49s/it]
# Predicting: 15it [01:42,  7.42s/it]
# Predicting: 16it [01:53,  8.74s/it]
# Predicting: 17it [01:59,  7.64s/it]
# Predicting: 18it [02:09,  8.44s/it]
# Predicting: 19it [02:12,  7.00s/it]
# Predicting: 20it [02:18,  6.70s/it]
# Predicting: 21it [02:25,  6.56s/it]
# Predicting: 22it [02:32,  6.71s/it]
# Predicting: 23it [02:38,  6.53s/it]
# Predicting: 24it [02:50,  8.08s/it]
# Predicting: 25it [02:50,  5.76s/it]
# Predicting: 26it [03:02,  7.58s/it]
# Predicting: 27it [03:11,  7.97s/it]
# Predicting: 28it [03:14,  6.67s/it]
# Predicting: 29it [03:26,  8.17s/it]
# Predicting: 30it [03:38,  9.26s/it]
# Predicting: 31it [03:39,  6.93s/it]
# Predicting: 32it [03:42,  5.62s/it]
# Predicting: 33it [03:46,  5.09s/it]
# Predicting: 34it [03:54,  6.03s/it]
# Predicting: 35it [03:58,  5.56s/it]
# Predicting: 36it [04:03,  5.24s/it]
# Predicting: 37it [04:05,  4.28s/it]
# Predicting: 38it [04:10,  4.39s/it]
# Predicting: 39it [04:21,  6.63s/it]
# Predicting: 40it [04:22,  4.74s/it]
# Predicting: 41it [04:25,  4.40s/it]
# Predicting: 42it [04:26,  3.39s/it]
# Predicting: 43it [04:34,  4.68s/it]
# Predicting: 44it [04:38,  4.47s/it]
# Predicting: 45it [04:45,  5.24s/it]
# Predicting: 46it [04:56,  6.85s/it]
# Predicting: 47it [04:56,  4.92s/it]
# Predicting: 48it [05:08,  6.98s/it]
# Predicting: 49it [05:13,  6.30s/it]
# Predicting: 50it [05:21,  6.44s/it]
# Generating:  90%|█████████ | 18/20 [1:17:04<08:40, 260.09s/it]
# Predicting: 0it [00:00, ?it/s]
# Predicting: 1it [00:10, 10.11s/it]
# Predicting: 2it [00:12,  5.28s/it]
# Predicting: 3it [00:21,  6.99s/it]
# Predicting: 4it [00:24,  5.71s/it]
# Predicting: 5it [00:36,  7.88s/it]
# Predicting: 6it [00:40,  6.48s/it]
# Predicting: 7it [00:45,  6.12s/it]
# Predicting: 8it [00:53,  6.76s/it]
# Predicting: 9it [01:00,  6.78s/it]
# Predicting: 10it [01:08,  7.07s/it]
# Predicting: 11it [01:09,  5.36s/it]
# Predicting: 12it [01:10,  3.83s/it]
# Predicting: 13it [01:10,  2.83s/it]
# Predicting: 14it [01:11,  2.13s/it]
# Predicting: 15it [01:23,  5.06s/it]
# Predicting: 16it [01:26,  4.59s/it]
# Predicting: 17it [01:26,  3.31s/it]
# Predicting: 18it [01:38,  5.80s/it]
# Predicting: 19it [01:39,  4.39s/it]
# Predicting: 20it [01:51,  6.51s/it]
# Predicting: 21it [01:52,  5.09s/it]
# Predicting: 22it [01:57,  5.01s/it]
# Predicting: 23it [02:01,  4.59s/it]
# Predicting: 24it [02:13,  6.77s/it]
# Predicting: 25it [02:14,  5.15s/it]
# Predicting: 26it [02:26,  7.16s/it]
# Predicting: 27it [02:36,  7.96s/it]
# Predicting: 28it [02:36,  5.80s/it]
# Predicting: 29it [02:44,  6.40s/it]
# Predicting: 30it [02:45,  4.63s/it]
# Predicting: 31it [02:50,  4.72s/it]
# Predicting: 32it [02:50,  3.43s/it]
# Predicting: 33it [03:02,  5.94s/it]
# Predicting: 34it [03:05,  4.96s/it]
# Predicting: 35it [03:09,  4.69s/it]
# Predicting: 36it [03:10,  3.63s/it]
# Predicting: 37it [03:16,  4.52s/it]
# Predicting: 38it [03:23,  5.15s/it]
# Predicting: 39it [03:24,  3.82s/it]
# Predicting: 40it [03:25,  3.12s/it]
# Predicting: 41it [03:26,  2.38s/it]
# Predicting: 42it [03:37,  5.16s/it]
# Predicting: 43it [03:38,  3.76s/it]
# Predicting: 44it [03:39,  3.05s/it]
# Predicting: 45it [03:44,  3.61s/it]
# Predicting: 46it [03:46,  3.15s/it]
# Predicting: 47it [03:47,  2.36s/it]
# Predicting: 48it [03:57,  4.77s/it]
# Predicting: 49it [04:09,  6.88s/it]
# Predicting: 50it [04:21,  5.23s/it]
# Generating:  95%|█████████▌| 19/20 [1:21:25<04:20, 260.47s/it]
# Predicting: 0it [00:00, ?it/s]
# Predicting: 1it [00:00,  1.30it/s]
# Predicting: 2it [00:12,  7.27s/it]
# Predicting: 3it [00:14,  4.78s/it]
# Predicting: 4it [00:18,  4.40s/it]
# Predicting: 5it [00:19,  3.10s/it]
# Predicting: 6it [00:20,  2.62s/it]
# Predicting: 7it [00:26,  3.67s/it]
# Predicting: 8it [00:27,  2.83s/it]
# Predicting: 9it [00:27,  2.02s/it]
# Predicting: 10it [00:37,  4.34s/it]
# Predicting: 11it [00:38,  3.41s/it]
# Predicting: 12it [00:50,  5.96s/it]
# Predicting: 13it [00:55,  5.75s/it]
# Predicting: 14it [00:56,  4.22s/it]
# Predicting: 15it [01:04,  5.28s/it]
# Predicting: 16it [01:04,  3.83s/it]
# Predicting: 17it [01:14,  5.72s/it]
# Predicting: 18it [01:16,  4.60s/it]
# Predicting: 19it [01:17,  3.37s/it]
# Predicting: 20it [01:20,  3.39s/it]
# Predicting: 21it [01:21,  2.60s/it]
# Predicting: 22it [01:27,  3.62s/it]
# Predicting: 23it [01:30,  3.40s/it]
# Predicting: 24it [01:42,  5.92s/it]
# Predicting: 25it [01:48,  6.21s/it]
# Predicting: 26it [01:49,  4.55s/it]
# Predicting: 27it [01:52,  4.05s/it]
# Predicting: 28it [01:53,  3.07s/it]
# Predicting: 29it [01:59,  4.00s/it]
# Predicting: 30it [02:00,  3.11s/it]
# Predicting: 31it [02:12,  5.73s/it]
# Predicting: 32it [02:18,  5.90s/it]
# Predicting: 33it [02:30,  7.71s/it]
# Predicting: 34it [02:35,  6.82s/it]
# Predicting: 35it [02:35,  4.92s/it]
# Predicting: 36it [02:42,  5.37s/it]
# Predicting: 37it [02:46,  4.94s/it]
# Predicting: 38it [02:47,  3.80s/it]
# Predicting: 39it [02:59,  6.22s/it]
# Predicting: 40it [03:06,  6.65s/it]
# Predicting: 41it [03:18,  8.07s/it]
# Predicting: 42it [03:18,  5.85s/it]
# Predicting: 43it [03:20,  4.69s/it]
# Predicting: 44it [03:21,  3.41s/it]
# Predicting: 45it [03:22,  2.74s/it]
# Predicting: 46it [03:29,  3.97s/it]
# Predicting: 47it [03:40,  6.05s/it]
# Predicting: 48it [03:47,  6.37s/it]
# Predicting: 49it [03:47,  4.59s/it]
# Predicting: 50it [03:48,  4.58s/it]
# Generating: 100%|██████████| 20/20 [1:25:14<00:00, 255.73s/it]
# Computing perplexity...
#   0%|          | 0/63 [00:00<?, ?it/s]
# Perplexity computed!
# Computing BLEU...
# BLEU computed!
# Computing ROUGE...
# ROUGE computed!

# %%
# ===== Results Summary =====
def print_results(results):
    print(f"\n{results['model_name']} Results:")
    print(f"  Perplexity: {results['perplexity']:.3f}") # lower is better
    print(f"  BLEU Score: {results['bleu']:.2f}")
    print(f"  ROUGE-1: {results['rouge1']:.2f}")
    print(f"  ROUGE-2: {results['rouge2']:.2f}")
    print(f"  ROUGE-L: {results['rougeL']:.2f}")

# print_results(base_results)
print_results(lora_results)
# Out:
# TinyLlama + LoRA Results:
#   Perplexity: 4.298
#   BLEU Score: 7.57
#   ROUGE-1: 36.05
#   ROUGE-2: 16.01
#   ROUGE-L: 28.18

# %%
# # ===== Results Summary =====
# print("\n" + "=" * 50)
# print("COMPREHENSIVE EVALUATION RESULTS")
# print("=" * 50)

# print(f"\nDataset Information:")
# print(f"- Full dataset size: {len(dataset):,}")
# print(f"- Train set: {len(train_split):,} samples (60%)")
# print(f"- Test set: {len(test_split):,} samples (40%)")
# print(f"- Evaluation sample size: {base_results['sample_size']:,}")
# print(f"- Perplexity sample size: {base_results['perplexity_sample_size']:,}")

# def print_results(results):
#     print(f"\n{results['model_name']} Results:")
#     print(f"  Perplexity: {results['perplexity']:.3f} (lower is better)")
#     print(f"  BLEU Score: {results['bleu']:.2f}")
#     print(f"  ROUGE-1: {results['rouge1']:.2f}")
#     print(f"  ROUGE-2: {results['rouge2']:.2f}")
#     print(f"  ROUGE-L: {results['rougeL']:.2f}")

# print_results(base_results)
# print_results(lora_results)

# # Improvement analysis
# print(f"\n=== IMPROVEMENT ANALYSIS ===")
# ppl_improvement = "↓" if lora_results['perplexity'] < base_results['perplexity'] else "↑"
# print(f"Perplexity: {base_results['perplexity']:.3f} → {lora_results['perplexity']:.3f} {ppl_improvement}")
# print(f"BLEU: {base_results['bleu']:.2f} → {lora_results['bleu']:.2f} ({lora_results['bleu'] - base_results['bleu']:+.2f})")
# print(f"ROUGE-1: {base_results['rouge1']:.2f} → {lora_results['rouge1']:.2f} ({lora_results['rouge1'] - base_results['rouge1']:+.2f})")
# print(f"ROUGE-2: {base_results['rouge2']:.2f} → {lora_results['rouge2']:.2f} ({lora_results['rouge2'] - base_results['rouge2']:+.2f})")
# print(f"ROUGE-L: {base_results['rougeL']:.2f} → {lora_results['rougeL']:.2f} ({lora_results['rougeL'] - base_results['rougeL']:+.2f})")

# # Sample comparison
# print(f"\n=== SAMPLE COMPARISONS ===")
# for i in range(min(3, len(base_results['predictions']))):
#     print(f"\n--- Sample {i+1} ---")
#     print(f"Reference: {base_results['references'][i]}")
#     print(f"Base: {base_results['predictions'][i]}")
#     print(f"LoRA: {lora_results['predictions'][i]}")

# %% [markdown]
# Gradio Chatbot Interface

# %%
# 1) Install dependencies
# !pip install -q gradio

# 2) Imports and Drive
import gradio as gr

from google.colab import drive
drive.mount('/content/drive')

# 3) Model Path
merged_dir = "/content/drive/MyDrive/Colab Notebooks/models/tinyllama-1.1b-merged"

device = "cuda" if torch.cuda.is_available() else "cpu"
# print(f"Using device: {device}")

# 4) Load model & tokenizer (no PEFT needed for merged model)
model = AutoModelForCausalLM.from_pretrained(
    merged_dir,
    torch_dtype=torch.float16 if device == "cuda" else torch.float32,
    device_map="auto" if device == "cuda" else None,
    trust_remote_code=True,
    low_cpu_mem_usage=True,
).to(device)
model.eval()

tokenizer = AutoTokenizer.from_pretrained(merged_dir, trust_remote_code=True)
if tokenizer.pad_token is None:
    tokenizer.pad_token = tokenizer.eos_token
tokenizer.padding_side = "right"

# 5) Chat settings
BOT_NAME = "LlamaBot"
gen_kwargs = dict(
    max_new_tokens=256,
    temperature=0.7,
    top_p=0.9,
    do_sample=True,
    pad_token_id=tokenizer.eos_token_id,
    eos_token_id=tokenizer.eos_token_id,
)

def build_chatml_from_messages(history_msgs, latest_user_message):
    # history_msgs: list of dicts with keys: role ('user'|'assistant'|'system'), content
    system = f"<|system|>\nYou are {BOT_NAME}, a helpful AI assistant.</s>\n"
    chatml = system
    for m in history_msgs or []:
        role = m.get("role")
        content = m.get("content", "")
        if role == "user":
            chatml += f"<|user|>\n{content}</s>\n"
        elif role == "assistant":
            chatml += f"<|assistant|>\n{content}</s>\n"
    chatml += f"<|user|>\n{latest_user_message}</s>\n<|assistant|>\n"
    return chatml

NAME_TRIGGERS = [
    "what's your name", "what is your name", "who are you", "tell me your name", "your name"
]

def chat_fn(message, history):
    # history is list[{"role": "...", "content": "..."}] with type="messages"
    msg_lower = (message or "").lower()
    if any(t in msg_lower for t in NAME_TRIGGERS):
        return f"My name is {BOT_NAME}, your friendly AI assistant."

    prompt = build_chatml_from_messages(history, message)
    inputs = tokenizer(prompt, return_tensors="pt").to(device)
    with torch.no_grad():
        outputs = model.generate(**inputs, **gen_kwargs)
    decoded = tokenizer.decode(outputs[0], skip_special_tokens=True)
    reply = decoded.split("<|assistant|>")[-1].strip()
    return reply

# 6) Gradio ChatInterface
ui = gr.ChatInterface(
    fn=chat_fn,
    type="messages",
    examples=["Hello!", "What's your name?", "Tell me a short story.",],
    title=f"{BOT_NAME}: TinyLlama-1.1B LoRA Chatbot",
    description=f"Chatbot powered by TinyLlama-1.1B with LoRA adapters",
    theme="soft",
)

ui.launch(share=True, debug=True)
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# Colab notebook detected. This cell will run indefinitely so that you can see errors and logs. To turn off, set debug=False in launch().
# * Running on public URL: https://691c3453e4f47cfd65.gradio.live
#
# This share link expires in 1 week. For free permanent hosting and GPU upgrades, run `gradio deploy` from the terminal in the working directory to deploy to Hugging Face Spaces (https://huggingface.co/spaces)
# <div><iframe src="https://691c3453e4f47cfd65.gradio.live" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>

# %%
# # 1. Install dependencies
# !pip install -q gradio accelerate peft bitsandbytes transformers torch

# # 2. Imports
# import torch
# import gradio as gr
# from transformers import AutoModelForCausalLM, AutoTokenizer
# from peft import PeftModel

# # 3. Model & Tokenizer Loading
# model_name = "TinyLlama/TinyLlama-1.1B-Chat-v1.0"
# adapter_dir = "tinyllama-1.1b-lora-finetuned"

# # Load base model (quantized if you used 4-bit during training, otherwise omit quantization_config)
# base_model = AutoModelForCausalLM.from_pretrained(
#     model_name,
#     torch_dtype=torch.float16,
#     device_map="auto",
#     trust_remote_code=True,
#     low_cpu_mem_usage=True,
# )

# # Inject LoRA adapter
# model = PeftModel.from_pretrained(base_model, adapter_dir)
# model.eval()

# # Load tokenizer
# tokenizer = AutoTokenizer.from_pretrained(model_name, trust_remote_code=True)
# tokenizer.pad_token = tokenizer.eos_token
# tokenizer.padding_side = "right"

# # 4. Inference Function
# def chat_with_tinyllama(user_message, chat_history=[]):
#     """
#     user_message: str, latest user query
#     chat_history: list of [user, bot] pairs for display
#     """
#     # Build ChatML prompt
#     system_msg = "<|system|>\nYou are a helpful AI assistant.</s>\n"
#     conversation = ""
#     for user, bot in chat_history:
#         conversation += f"<|user|>\n{user}</s>\n<|assistant|>\n{bot}</s>\n"
#     conversation += f"<|user|>\n{user_message}</s>\n<|assistant|>\n"

#     # Tokenize and generate
#     inputs = tokenizer(conversation, return_tensors="pt").to(model.device)
#     with torch.no_grad():
#         outputs = model.generate(
#             **inputs,
#             max_new_tokens=128,
#             temperature=0.7,
#             top_p=0.9,
#             pad_token_id=tokenizer.eos_token_id,
#             eos_token_id=tokenizer.eos_token_id,
#         )
#     decoded = tokenizer.decode(outputs[0], skip_special_tokens=True)
#     # Extract the assistant’s completion
#     reply = decoded.split("<|assistant|>")[-1].strip()
#     # Append and return updated history
#     chat_history = chat_history + [(user_message, reply)]
#     return chat_history, chat_history

# # 5. Gradio Interface
# with gr.Blocks() as demo:
#     gr.Markdown("## TinyLlama-1.1B Chatbot (LoRA Fine-Tuned)")
#     chatbot = gr.Chatbot()
#     msg    = gr.Textbox(placeholder="Type your message here…", show_label=False)
#     clear  = gr.Button("Clear")

#     msg.submit(fn=chat_with_tinyllama, inputs=[msg, chatbot], outputs=[chatbot, chatbot])
#     clear.click(lambda: None, None, chatbot, queue=False)

# # 6. Launch
# demo.launch(share=True)
